# %%
import re
import os
import json
import spacy
import random
import pdfplumber
from typing import Optional
from spacy.training import Example

# %%
TRAIN_DATA = [
    (
        # Ejemplo 1
        '2353 17ABR2024 LEY  No. "POR  MEDIO  DE  LA  CUAL  SE  RECONOCE  COMO  PATRIMONIO '
        'CULTURAL  INMATERIAL  DE  LA NACION  EL  FESTIVAL  PROVINCIANO  DE  ACORDEONES,  CANCION '
        'INÉDITA  Y  PIQUERIA,  DEL  MUNICIPIO  DE  PIVIJAY  -  MAGDALENA  Y  SE  DICTAN  OTRAS '
        'DISPOSICIONES" El  Congreso  de  Colombia,',
        {"entities": [
            (0, 4, "NUMERO_LEY"),         # "2353"
            (5, 15, "FECHA"),              # "17ABR2024"
            (25, 272, "EPIGRAFE")          # desde la apertura de comillas hasta justo antes de "El Congreso..."
        ]}
    ),
    (
        # Ejemplo 2 (nota: la fecha se compone de "17MAY" y "2024" separados en el texto; en la anotación se unen)
        '2355 2024 LEY  No. 17MAY "POR  MEDIO  DEL  CUAL  SE  RECONOCE  EL  FESTIVAL  DEPARTAMENTAL '
        'DE  BANDAS  DE  CUNDINAMARCA  COMO  MANIFESTACION  DEL  PATRIMONIO  CULTURAL  INMATERIAL '
        'DE  LA  NACION" El  Congreso  de  Colombia,',
        {"entities": [
            (0, 4, "NUMERO_LEY"),         # "2355"
            (5, 9, "FECHA"),              # "2024" puede interpretarse junto a "17MAY" (ver nota abajo)
            (19, 24, "FECHA"),            # "17MAY"
            (25, 196, "EPIGRAFE")         # epígrafe entre comillas
        ]}
    ),
    (
        # Ejemplo 3: La fecha viene separada en tres líneas ("2356", "8", "2024" y luego "MAY")
        '2356 8 2024 LEY  No. MAY "POR  MEDIO  DE  LA  CUAL  SE  ELIMINAN  BENEFICIOS  Y  SUBROGADOS '
        'PENALES  PARA  QUIENES  SEAN  CONDENADOS  O  ESTÉN  CUMPLIENDO  DETENCION  PREVENTIVA '
        'POR  EL  DELITO  DE  FEMINICIDIO" El  Congreso  de  Colombia,',
        {"entities": [
            (0, 4, "NUMERO_LEY"),         # "2356"
            (5, 6, "FECHA"),              # "8" (día)
            (7, 11, "FECHA"),             # "2024" (año)
            (21, 24, "FECHA"),            # "MAY" (mes)
            (25, 211, "EPIGRAFE")
        ]}
    ),
    (
        # Ejemplo 4: Uso de "EL CONGRESO DE LA REPUBLICA DE COLOMBIA" para marcar el fin del epígrafe
        'LEY  No.2361 14JUNZUZ4 POR  MEDIO  DEL  CUAL  SE  OTORGAN  LINEAMIENTOS  PARA  LA '
        'CREACION  DE  LA  POLITICA  PUBLICA  DE  LACTANCIA  MATERNA,  ALIMENTACION  COMPLEMENTARIA,  '
        'Y  LA  PROMOCION  DE  LOS  BANCOS  DE  LECHE  HUMANA  COMO  COMPONENTE  ANATOMICO  '
        'EL  CONGRESO  DE  LA  REPUBLICA  DE  COLOMBIA  DECRETA:',
        {"entities": [
            (8, 12, "NUMERO_LEY"),         # "2361"
            (13, 22, "FECHA"),              # "14JUNZUZ4" (aquí convendría aplicar correcciones manuales o reglas post-procesado)
            (23, 258, "EPIGRAFE")           # Desde "POR MEDIO DE..." hasta antes de "EL CONGRESO..."
        ]}
    ),
    (
        # Ejemplo 5: Problema en la fecha "14JU Te" y epígrafe sin comillas
        '14JU Te LEY  No.  2360 POR  MEDIO  DE  LA  CUAL  SE  MODIFICA  Y  ADICIONA  LA  LEY  1384  DE  2010 '
        'RECONOCIENDO  PARA  LOS  EFECTOS  DE  ESTA  LEY  COMO  SUJETOS  DE  ESPECIAL  PROTECCION  CONSTITUCIONAL  A  LAS  '
        'PERSONAS  CON SOSPECHA  O  QUE  PADECEN  CANCER EL  CONGRESO  DE  LA  REPUBLICA DECRETA:',
        {"entities": [
            (0, 4, "FECHA"),
            (18, 22, "NUMERO_LEY"),         
            (23, 261, "EPIGRAFE")
        ]}
        
        # # Ejemplo 5: Problema en la fecha "14JU Te" y epígrafe sin comillas
        # '8 FEB 2022\n-\nLEY ORGÁNICA No2199\nLEY ORGANICA No2199 FEB 2022 --------~~~~~~~~~--- "POR MEDIO DE LA CUAL SE DESARROLLA EL ARTÍCULO 325 DE LA "POR MEDIO DE LA CUAL SE DESARROLLA EL ARTICULO LA CONSTITUCIÓN POLÍTICA Y SE EXPIDE EL RÉGIMEN ESPECIAL DE LA CONSTITUCION POLITICA Y SE EXPIDE EL RÉGIMEN ESPECIAL DE LA REGIÓN METROPOLITANA BOGOTÁ - CUNDINAMARCA" REGION METROPOLITANA BOGOTA CUNDINAMARCA" EL CONGRESO DE COLOMBIA EL CONGRESO DE COLOMBIA DECRETA: ',
        # {"entities": [
        #     (0, 4, "FECHA"),
        #     (18, 22, "NUMERO_LEY"),         
        #     (23, 261, "EPIGRAFE")
        # ]}
    )
]

# %%
def fix_ocr_artifacts(text: str) -> str:
    # 1) Eliminar líneas repetidas
    lines = text.split("\n")
    new_lines = []
    last_line = None
    for line in lines:
        if line == last_line:
            continue
        new_lines.append(line)
        last_line = line
    text = "\n".join(new_lines)

    # 2) Unir caracteres separados por guiones/tildes
    #    "1-7-A-BR-2-0-24" -> "17ABR2024", "2-3-5-1-" -> "2351"
    text = re.sub(r"([A-Z0-9])[\-\~]+([A-Z0-9])", r"\1\2", text, flags=re.IGNORECASE)

    # 3) Quitar espacios redundantes
    text = re.sub(r"\s+", " ", text).strip()
    return text

# %%
def remove_duplicate_letters(text: str) -> str:
    """
    Reemplaza secuencias de caracteres repetidos (ej. 'AA', 'MMM') 
    por una sola ocurrencia (ej. 'A', 'M').
    Efecto: 'AAMMPPLLIAI' -> 'AMPLIAI'.
    """
    return re.sub(r'(.)\1+', r'\1', text)

# %%
def limit_repetitions_to_two(text: str) -> str:
    """
    Si encuentra 3 o más repeticiones consecutivas (ej. 'AAAA'), 
    las reduce a 2 (-> 'AA').
    """
    return re.sub(r'(.)\1{2,}', r'\1\1', text)

# %%
def unify_hyphens_and_tildes(text: str) -> str:
    """
    Elimina guiones (~, -) entre letras o dígitos consecutivos,
    p.ej. '1-7-A-BR-2-0-24' -> '17ABR2024'.
    """
    import re
    return re.sub(r"([A-Z0-9])[\-\~]+([A-Z0-9])", r"\1\2", text, flags=re.IGNORECASE)

# %%
def remove_exact_duplicate_lines(text: str) -> str:
    lines = text.split("\n")
    new_lines = []
    last_line = None
    for line in lines:
        if line == last_line:
            continue
        new_lines.append(line)
        last_line = line
    return "\n".join(new_lines)

# %%
##############################################################################
# 1. Función para limpiar el texto OCR: fix_ocr_issues
##############################################################################
def fix_ocr_issues(text: str) -> str:
    """
    Aplica correcciones y filtros a texto proveniente de OCR.
    - Elimina líneas basura.
    - Corrige palabras mal reconocidas.
    - Normaliza saltos de línea y espacios.
    """
    
    # 1) Eliminar líneas repetidas exactas
    text = remove_exact_duplicate_lines(text)

    # 2) Unificar guiones/tildes entre letras o dígitos
    text = unify_hyphens_and_tildes(text)

    # 3) Reducir repeticiones de caracteres (opción 1)
    # text = remove_duplicate_letters(text)

    # o Limitar a 2 repeticiones (opción 2)
    text = limit_repetitions_to_two(text)
    
    # Correcciones específicas
    correcciones = {
        "NACiÓN": "NACIÓN",
        "Colr,mbiana": "Colombiana",
        "Perscnal": "Personal",
        "AérEa": "Aérea",
        "No1956": "No 1956",
        "No.1956": "No. 1956",
        "N°1956": "N° 1956",
        "LEYNo": "LEY No",
        "LEYNo.": "LEY No.",
        "4JUN2019": "4 JUN 2019",
        "Dadaen": "Dada en",
    }
    for error, correccion in correcciones.items():
        text = text.replace(error, correccion)
    
    # Llamar a la nueva función de artefactos
    text = fix_ocr_artifacts(text)

    # Eliminar líneas formadas solo por guiones, tildes o espacios
    lines = text.split("\n")
    clean_lines = []
    for line in lines:
        # Ajusta el patrón si tienes más símbolos basura
        if re.match(r"^[\-\~\s]+$", line.strip()):
            continue
        clean_lines.append(line)
    text = "\n".join(clean_lines)

    # Normalizar saltos de línea y espacios
    text = re.sub(r"(?<=\S)\n(?=\S)", " ", text)  # une líneas sin espacio
    text = re.sub(r"\n{2,}", "\n\n", text)        # limita saltos sucesivos
    text = re.sub(r"[ \t]+", " ", text)           # compacta espacios
    text = text.strip()

    # Correcciones finales (ejemplo: separar "No1234")
    text = re.sub(r"(No|N°)(\d+)", r"\1 \2", text, flags=re.IGNORECASE)
    # Espacios entre dígitos y texto (ej. "17ABR2024" -> "17 ABR2024")
    text = re.sub(r"(\d+)([A-Z]{1,3}\d{4})", r"\1 \2", text)

    return text

# %%
##############################################################################
# 2. Función para parsear fechas con regex: parse_date_str
##############################################################################
def parse_date_str(text: str) -> str | None:
    patterns = [
        r"(\d{1,2})\s*(?:de\s*)?([A-Z]+)\s*(?:de\s*)?(\d{4})",  # 4 JUN 2019, 4 de JUNIO de 2019
        r"(\d{1,2})\s+([A-Z]{3,})\s+(\d{4})", #4 JUN 2019
    ]
    month_map = {  # Mapeo de nombres de mes a números (en mayúsculas)
        "ENE": "01", "FEB": "02", "MAR": "03", "ABR": "04",
        "MAY": "05", "JUN": "06", "JUL": "07", "AGO": "08",
        "SEP": "09", "OCT": "10", "NOV": "11", "DIC": "12",
        "ENERO": "01", "FEBRERO": "02", "MARZO": "03", "ABRIL": "04",
        "MAYO": "05", "JUNIO": "06", "JULIO": "07", "AGOSTO": "08",
        "SEPTIEMBRE": "09", "OCTUBRE": "10", "NOVIEMBRE": "11", "DICIEMBRE": "12"
    }

    for pattern in patterns:
        match = re.search(pattern, text, re.IGNORECASE)
        if match:
            try:
                day = match.group(1).zfill(2)
                month = month_map.get(match.group(2).upper())
                year = match.group(3)

                if month:
                    return f"{day}/{month}/{year}"
            except ValueError:
                continue
    return None

# %%
##############################################################################
# 3. Función para parsear tipo de ley y número de ley: parse_ley_and_type
##############################################################################
def parse_ley_and_type(text: str):
    type_map = {
        "orgánica": "orgánica",
        "organica": "orgánica",
        "ordinaria": "ordinaria",
        "estatutaria": "estatutaria",
        "estaturaria": "estatutaria",  # Podría haber errores de OCR
    }

    pattern = r"""
        (?:LEY|LEYES)[\s\n]*  # "LEY" o "LEYES", seguido de espacios/saltos
        (?:             # Grupo opcional para el tipo de ley
            (ESTATUTARIA|ORDINARIA|ORG[AÁ]NICA)  # Tipos de ley
            [\s\n]*     # 1 o más espacios/saltos DESPUÉS del tipo
        )?              # El tipo de ley es OPCIONAL
        (?:N[°ºc]?\.?|No\.?)?  # "N", "No", "N°", "Nº", "No.", "N.", "Nc.", opcional
        [\s\n]*         # 0 o más espacios/saltos
        (\d+)          # Captura el número de la ley
        (?:['´`‘’])?   # Caracteres especiales opcionales después del número
    """
    match = re.search(pattern, text, re.IGNORECASE | re.VERBOSE | re.DOTALL)

    if not match:
        return (None, None)  # Si no hay coincidencia, devuelve (None, None)

    raw_type = match.group(1)  # Captura el grupo 1 (tipo de ley, si existe)
    ley_number = match.group(2)  # Captura el grupo 2 (número de ley)

    if raw_type:
        tipo_ley = type_map.get(raw_type.lower()) #Uso del diccionario
    else:
        tipo_ley = "orgánica"  # Si no hay tipo explícito, asume "orgánica"

    return (tipo_ley, ley_number)

# %%
##############################################################################
# 4. Validaciones mínimas: looks_like_number_ley, looks_like_date, looks_like_epigrafe
##############################################################################
def looks_like_number_ley(value: str) -> bool:
    """
    Chequeo mínimo: ¿contiene dígitos?
    """
    return bool(re.search(r"\d+", value)) if value else False


def looks_like_date(candidate: str) -> bool:
    """
    Intenta parsear 'candidate' con parse_date_str.
    Retorna True si lo parsea, False si no.
    """
    return parse_date_str(candidate) is not None


def looks_like_epigrafe(text_epigrafe: str) -> bool:
    """
    Verifica que el epígrafe cumpla criterios mínimos:
    - Longitud
    - Contenga la frase "POR MEDIO DE" (u otra)
    """
    if not text_epigrafe:
        return False
    if len(text_epigrafe) < 30:  # ajusta a tu criterio
        return False
    if "POR MEDIO DE" not in text_epigrafe.upper():
        return False
    return True

# %%
##############################################################################
# 5. Función para remover la segunda ocurrencia de "POR MEDIO DE LA CUAL"
#    o cualquier frase que se repita en el epígrafe.
##############################################################################
def remove_second_phrase_occurrence(text: Optional[str], phrase: str) -> Optional[str]:
    """
    Elimina la segunda ocurrencia de 'phrase' en 'text'.
    Si 'text' es None o no contiene dos ocurrencias, no hace nada.
    """
    if not text:
        return text

    text_upper = text.upper()
    phrase_upper = phrase.upper()

    first_idx = text_upper.find(phrase_upper)
    if first_idx == -1:
        return text  # No aparece ni una vez

    second_idx = text_upper.find(phrase_upper, first_idx + len(phrase))
    if second_idx == -1:
        return text  # Solo hay una ocurrencia

    # Eliminar la segunda ocurrencia de 'phrase' (solo la frase, no todo el texto siguiente)
    before = text[:second_idx]
    after = text[second_idx + len(phrase):]
    return before + after

# %%
##############################################################################
# 6. Fallback para extraer epígrafe (con fecha y sin fecha)
##############################################################################
def extraer_epigrafe_fallback(text: str, final_fecha: Optional[str]) -> Optional[str]:
    """
    Intenta extraer el epígrafe anclado a la fecha (si la hay).
    Si falla, hace fallback a una búsqueda sin fecha.
    """
    if final_fecha:
        pattern_with_date = rf"{re.escape(final_fecha)}.*?(POR\s+MEDIO\s+DE\s+LA\s+CUAL\s+.*?)(?:\.\s*|\n|EL\s+CONGRESO)"
        match = re.search(pattern_with_date, text, re.IGNORECASE | re.DOTALL)
        if match:
            return match.group(1).strip()

    # Si no encuentra anclado a la fecha, buscamos sin fecha
    pattern_no_date = r"(POR\s+MEDIO\s+DE\s+LA\s+CUAL\s+.*?)(?:\.\s*|\n|EL\s+CONGRESO)"
    match = re.search(pattern_no_date, text, re.IGNORECASE | re.DOTALL)
    if match:
        return match.group(1).strip()

    return None

# %%
##############################################################################
# 7. Función para extraer metadatos con spaCy (NER): spacy_extract_metadata
##############################################################################
def spacy_extract_metadata(text: str, nlp) -> dict:
    doc = nlp(text)
    
    # Depuración: imprime las entidades detectadas
    print("=== spaCy Entities ===")
    for ent in doc.ents:
        print(f"Texto: {ent.text} | Label: {ent.label_}")

    result = {
        "numero_ley": None,
        "fecha": None,
        "epigrafe": None
    }
    for ent in doc.ents:
        if ent.label_ == "NUMERO_LEY":
            result["numero_ley"] = ent.text
        elif ent.label_ == "FECHA":
            result["fecha"] = ent.text
        elif ent.label_ == "EPIGRAFE":
            result["epigrafe"] = ent.text
    return result

# %%
##############################################################################
# 8. Normalizar la fecha de spaCy con parse_date_str
##############################################################################
def normalize_spacy_date(spacy_fecha: Optional[str]) -> Optional[str]:
    """
    Intenta parsear la fecha devuelta por spaCy con parse_date_str.
    Si es válida, retorna la versión dd/mm/yyyy. Si no, None.
    """
    if not spacy_fecha:
        return None
    parsed = parse_date_str(spacy_fecha)
    return parsed  # None si falla, o "08/02/2022" si funciona

# %%
##############################################################################
# 9. Función principal híbrida: extract_metadata_layout_hybrid
##############################################################################
def extract_metadata_layout_hybrid(text_lineal: str, nlp) -> dict:
    """
    Combina spaCy + regex para extraer: numero_ley, fecha, tipo_ley, epigrafe.
    Usa fallback en caso de datos inconsistentes.
    """
    # Limpieza
    text_lineal = fix_ocr_issues(text_lineal)

    # 1) Extraer con spaCy
    spacy_result = spacy_extract_metadata(text_lineal, nlp)

    # 2) Regex
    tipo_ley, ley_number = parse_ley_and_type(text_lineal)
    fecha_regex = parse_date_str(text_lineal)

    # 3) Normalizar la fecha de spaCy
    spacy_fecha = spacy_result["fecha"]
    spacy_fecha_normalizada = normalize_spacy_date(spacy_fecha)

    # 4) Decidir la fecha final
    if spacy_fecha_normalizada:
        final_fecha = spacy_fecha_normalizada
    else:
        final_fecha = fecha_regex

    # 5) Epígrafe (anclado a la fecha y fallback sin fecha)
    epigrafe_regex = extraer_epigrafe_fallback(text_lineal, final_fecha)

    # 6) Número de ley (fallback)
    spacy_numero_ley = spacy_result["numero_ley"]
    if not spacy_numero_ley or not looks_like_number_ley(spacy_numero_ley):
        spacy_numero_ley = ley_number

    # 7) Epígrafe (fallback spaCy vs regex)
    spacy_epigrafe = spacy_result["epigrafe"]
    if spacy_epigrafe and looks_like_epigrafe(spacy_epigrafe):
        final_epigrafe = spacy_epigrafe
    else:
        final_epigrafe = epigrafe_regex

    # 8) (Opcional) Eliminar segunda ocurrencia de "POR MEDIO DE LA CUAL"
    final_epigrafe = remove_second_phrase_occurrence(final_epigrafe, "POR MEDIO DE LA CUAL")

    # 9) Armar el dict final
    combined = {
        "numero_ley": spacy_numero_ley,
        "fecha": final_fecha,
        "tipo_ley": tipo_ley,
        "epigrafe": final_epigrafe,
    }
    return combined

# %%
##############################################################################
# 10. Función para procesar TODAS las páginas y combinar resultados
##############################################################################
def extract_metadata_from_pdf_all_pages(pdf_path: str, nlp=None) -> dict:
    final_metadata = {
        "numero_ley": None,
        "fecha": None,
        "tipo_ley": None,
        "epigrafe": None
    }

    with pdfplumber.open(pdf_path) as pdf:
        for page_index, page in enumerate(pdf.pages):
            page_text = page.extract_text() or ""
            # Limpieza OCR
            page_text = fix_ocr_issues(page_text)

            # Extraer metadatos de ESTA página
            partial_metadata = extract_metadata_layout_hybrid(page_text, nlp)

            # Combinar resultados
            # Reglas de ejemplo (ajusta a tu gusto)
            # 1) Si no hay numero_ley, tomarlo
            if partial_metadata["numero_ley"] and not final_metadata["numero_ley"]:
                final_metadata["numero_ley"] = partial_metadata["numero_ley"]

            # 2) Para la fecha, si no la tenemos, la tomamos
            if partial_metadata["fecha"] and not final_metadata["fecha"]:
                final_metadata["fecha"] = partial_metadata["fecha"]

            # 3) tipo_ley: sobrescribir si se detecta en alguna página
            if partial_metadata["tipo_ley"]:
                final_metadata["tipo_ley"] = partial_metadata["tipo_ley"]

            # 4) epigrafe: si no existe en final o el nuevo es más largo, lo sobrescribimos
            if partial_metadata["epigrafe"]:
                if not final_metadata["epigrafe"]:
                    final_metadata["epigrafe"] = partial_metadata["epigrafe"]
                else:
                    if len(partial_metadata["epigrafe"]) > len(final_metadata["epigrafe"]):
                        final_metadata["epigrafe"] = partial_metadata["epigrafe"]

            # (Opcional) Parar si ya tenemos todo
            # if all(final_metadata[k] for k in final_metadata):
            #     break

    return final_metadata

# %%
##############################################################################
# 11. (Opcional) Entrenar y cargar un modelo spaCy
##############################################################################
def train_spacy_model(train_data, output_dir="modelo_leyes_epigrafe"):
    """
    Entrena un modelo spaCy NER con tus entidades personalizadas 
    (NUMERO_LEY, FECHA, EPIGRAFE, etc.).
    """
    nlp = spacy.blank("es")
    if "ner" not in nlp.pipe_names:
        ner = nlp.add_pipe("ner", last=True)
    else:
        ner = nlp.get_pipe("ner")

    # Añadir etiquetas
    for text, annotations in train_data:
        for start, end, label in annotations["entities"]:
            ner.add_label(label)

    nlp.initialize()

    examples = []
    for text, annotations in train_data:
        doc = nlp.make_doc(text)
        example = Example.from_dict(doc, annotations)
        examples.append(example)

    for i in range(10):
        random.shuffle(examples)
        losses = {}
        for example in examples:
            nlp.update([example], losses=losses)
        print(f"Época {i}, pérdidas: {losses}")

    nlp.to_disk(output_dir)
    print(f"Modelo guardado en: {output_dir}")
    return nlp

# %%
def load_spacy_model(model_path="modelo_leyes_epigrafe"):
    """
    Carga el modelo spaCy entrenado desde disco.
    """
    return spacy.load(model_path)

nlp_trained = load_spacy_model("modelo_leyes_epigrafe")

# %%
def procesar_pdfs_en_carpeta(carpeta_pdf, carpeta_salida, nlp):
    """
    Procesa todos los archivos PDF en una carpeta y guarda los metadatos en archivos JSON separados,
    usando la función extract_metadata_from_pdf_all_pages.
    """
    # Crear carpeta de salida si no existe
    os.makedirs(carpeta_salida, exist_ok=True)

    for archivo in os.listdir(carpeta_pdf):
        if archivo.lower().endswith(".pdf"):
            ruta_pdf = os.path.join(carpeta_pdf, archivo)

            # Llama a la función que procesa todas las páginas del PDF
            metadatos = extract_metadata_from_pdf_all_pages(ruta_pdf, nlp)

            # Nombre de salida JSON
            nombre_json = os.path.splitext(archivo)[0] + ".json"
            ruta_json = os.path.join(carpeta_salida, nombre_json)

            # Guardar en JSON
            with open(ruta_json, "w", encoding="utf-8") as f:
                json.dump(metadatos, f, ensure_ascii=False, indent=4)

            print(f"Metadatos guardados en: {ruta_json}")


# --- Ejemplo de Uso --- #
if __name__ == "__main__":
    # Rutas de carpeta
    carpeta_pdf = r"c:/Users/Jorge/OneDrive/Documents/proyect/document/leyes"
    carpeta_salida = r"c:/Users/Jorge/OneDrive/Documents/proyect/document/json_output_2024"

    # Cargar tu modelo spaCy (si ya lo tienes entrenado)
    nlp_trained = load_spacy_model("modelo_leyes_epigrafe")  # ejemplo
    # O si estás usando un EntityRuler, define nlp_trained antes.

    # Llamar a la función
    procesar_pdfs_en_carpeta(carpeta_pdf, carpeta_salida, nlp_trained)
# Out:
# === spaCy Entities ===
# Texto: 8 | Label: FECHA
# Texto: FEB | Label: FECHA
# Texto: 2022 | Label: NUMERO_LEY
# Texto: FEB | Label: FECHA
# Texto: 2022 | Label: NUMERO_LEY
# Texto: ° | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: itali nta an a BB oo gg oo tatá - CC uu nn dd ini an mam arca ar ,c a, dd ee fif nin ir ir yy rr ee gg lala mm ene tn at ra r ssuu ff uu nn cc ioi no an ma im enie ton , to, eenn eell mm aa rr cc oo dd ee ll aa aa uu tt oo nn oo mm iaí a rr ee cc oo nn oo cc idi ad a aa ss uu ss ii nn tt ee gg rara ntn et se s pp oo rr ll aa CCoonnsstittiutucicoinó n PP oo ll ií tt icic aa . AA RR TT ICÍC ULU OL O 22 °° | Label: EPIGRAFE
# Texto: ibi | Label: FECHA
# Texto: lb | Label: FECHA
# Texto: ií | Label: FECHA
# Texto: ut | Label: FECHA
# Texto: nu | Label: FECHA
# Texto: oó | Label: FECHA
# Texto: ici | Label: FECHA
# Texto: trt | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: vati | Label: FECHA
# Texto: ir | Label: FECHA
# Texto: oto | Label: FECHA
# Texto: tt | Label: FECHA
# Texto: ic | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: idid | Label: FECHA
# Texto: vati | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: ip | Label: FECHA
# Texto: EEll | Label: FECHA
# Texto: serán | Label: FECHA
# === spaCy Entities ===
# Texto: 2199 | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: 0 | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: mam | Label: FECHA
# Texto: rt | Label: NUMERO_LEY
# Texto: io | Label: FECHA
# Texto: s | Label: FECHA
# Texto: oto | Label: FECHA
# Texto: ene | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: drd | Label: FECHA
# Texto: rir | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: 2 | Label: FECHA
# Texto: velara | Label: FECHA
# Texto: iei | Label: FECHA
# Texto: ian | Label: FECHA
# Texto: ió | Label: FECHA
# Texto: cam | Label: FECHA
# Texto: ica | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: trt | Label: FECHA
# Texto: trt | Label: FECHA
# Texto: tteerritiotoriori | Label: FECHA
# Texto: 44 | Label: FECHA
# Texto: .. | Label: FECHA
# Texto: 55 | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: if | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: 6 | Label: FECHA
# Texto: im | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: 8 | Label: FECHA
# Texto: los | Label: FECHA
# Texto: temas | Label: FECHA
# Texto: 8 | Label: FECHA
# Texto: los | Label: FECHA
# Texto: por | Label: FECHA
# === spaCy Entities ===
# Texto: .. | Label: NUMERO_LEY
# Texto: 2·99 | Label: FECHA
# Texto: 2199 | Label: NUMERO_LEY
# Texto: su | Label: FECHA
# Texto: 10 | Label: FECHA
# Texto: 1l1 | Label: FECHA
# Texto: 1 | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: por | Label: FECHA
# Texto: los | Label: FECHA
# Texto: los | Label: FECHA
# Texto: 6 | Label: FECHA
# Texto: Por | Label: FECHA
# Texto: iniciativa del Alcalde Mayor y del LA REGION METROPOLITANA. Por iniciativa del Alcalde Mayor y del Gobernador respectivamente, el Concejo Distrital de Bogotá, por medio de Gobernador respectivamente, el Concejo Distrital de Bogota, por medio de Acuerdo Distrital, y la Asamblea Departamental de Cundinamarca, por medio de ordenanza departamental, decidirán respectivamente sobre su ingreso a la ordenanza departamental, decidiran respectivamente sobre su ingreso a la RR ee gg ioió nn MM ee trt oro pp olo italit na an a BB oo gg oo tatá -- CC uu nn dd inin amam ara carc , a, cc oo nn lolo cc uu aa l l lala RR ee gg ioió nn Metropolitana entrará en funcionamiento, de conformidad con el Parágrafo Metropolitana entrara en funcionamiento, de conformidad con el Paragrafo Transitorio 1 del artículo 325 del Constitución Política. Transitorio 1 del articulo 325 del Constitucion Politica. Los mecanismos y procedimientos de esta decisión serán los dispuestos en el Los mecanismos y procedimientos de esta decision seran los dispuestos en el reglamento de cada una de las corporaciones. Una vez radicado el Proyecto de Acuerdo o el Proyecto de Ordenanza correspondiente, las corporaciones deberán Acuerdo 0 el Proyecto de Ordenanza correspondiente, las corporaciones deberan adelantar al menos una audiencia pública, donde se propenda por la adelantar al menos una audiencia publica, donde se propenda por la representatividad y pluralidad territorial. PARÁGRAFO 1°. La totalidad de los Concejos Municipales y las Alcaldías PARAGRAFO 1°. La totalidad de los Concejos Municipales y las Alcaldias Municipales del Departamento de Cundinamarca podrán participar en las Municipales del Departamento de Cundinamarca podran participar en las audiencias públicas que adelante la Asamblea Departamental. audiencias publicas que adelante la Asamblea Departamental. PP AA RR AÁ GG RAR FA OF O 22 °° | Label: EPIGRAFE
# Texto: audiencias públicas que adelante el Distrito Capital podran participar en las audiencias publicas que adelante el Concejo de Bogotá. Concejo de Bogota. AA RR TT ICÍ UC LU OL O 77 °° | Label: EPIGRAFE
# Texto: uu | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: ip | Label: FECHA
# === spaCy Entities ===
# Texto: 2199 | Label: NUMERO_LEY
# Texto: una | Label: FECHA
# Texto: una | Label: FECHA
# Texto: 0 | Label: FECHA
# Texto: Una | Label: FECHA
# Texto: Una | Label: FECHA
# Texto: vez | Label: FECHA
# Texto: aprobado conforme al menos un cabildo abierto. El proyecto debera ser aprobado conforme al reglamento del respectivo concejo. PARÁGRAFO 10. Los municipios que conformen la Región Metropolitana PARAGRAFO 1°. Los municipios que conformen la Region Metropolitana mantendrán su autonomía territorial, no quedarán incorporados al Distrito mantendran su autonomia territorial, no quedaran incorporados al Distrito Capital, y ejercerán sus competencias a través de la región en aquellas materias Capital, y ejerceran sus competencias a través de la region en aquellas materias definidas como hechos metropolitanos y deberán armonizar sus planes y definidas como hechos metropolitanos y deberan armonizar sus planes y programas a aquellos que en el marco de sus competencias adopte la región. programas a aquellos que en el marco de sus competencias adopte la region. ARTÍCULO 8 0 ÁMBITO GEOGRÁFICO. Facúltese al Consejo Regional para ARTICULO 8° | Label: EPIGRAFE
# Texto: los | Label: FECHA
# Texto: los | Label: FECHA
# Texto: interés | Label: FECHA
# Texto: interés | Label: FECHA
# Texto: las | Label: FECHA
# Texto: las | Label: FECHA
# Texto: ic | Label: FECHA
# Texto: 44 | Label: FECHA
# === spaCy Entities ===
# Texto: 2 | Label: FECHA
# Texto: ~ | Label: FECHA
# Texto: 99 | Label: FECHA
# Texto: 2199 | Label: NUMERO_LEY
# Texto: 22 | Label: FECHA
# Texto: l | Label: FECHA
# Texto: oorrddeenn | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: itali nta an . a. 33 .. LLaass qq uu ee ss ee aa nn dd ee lele gg aa dd asa s pp oo rr ll aa ss eennttididaaddese s qq uu ee ll aa ss ccoonnffoormrmana.n . 44 .. LL aa ss qq uu ee ll aa ss eennttiiddaaddese s qq uu ee llaa ccoonnfoformrmene n ddeeccididaann ee jj ee rcrc ee r r eenn ff oo rr mm aa cc oo nn juju ntn at a pp rr ee vv iaia cc aa lil fi if cic aa cic oi nó n dd ee ll aa mmaatteeriraia cc oo mm oo uu nn hheecchhoo mm ee trt or po op lio tali nta o.n o. 55.. LL aa ss qq uu ee ss ee aa nn ddeefifninididasa s eenn eell aa cc tt oo dd ee ccoonnsstittiutcuicoinó n dd ee ll aa RR ee gg ioió nn MM ee trt oro pp olo italit na an a Bogotá - Cundinamarca. Bogota Cundinamarca. 66 .. LL aa dd ee fif nin ici | Label: EPIGRAFE
# Texto: itl | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: áreas | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: ií | Label: FECHA
# Texto: ° | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: ncn ic | Label: EPIGRAFE
# Texto: vi | Label: FECHA
# Texto: ioió | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: itali nta an a ccoonnffoormrme e aa ss uu eennttrraaddaa ee nn ff uu nn cc ioio nn amam ienie ton to yy dd ee aaccuueerdrdoo cc oo nn llaa aa ss igig nn aa cc ioi nó n dd ee rreeccuursrsoos s pp rr ee vv isis tata pp aa rr aa ccaaddaa uu nn aa dd ee ee ll ala ss , , aa ss ií cc oo mm oo ll aa ss dd ee mm aá s rr ee gg lala ss qq uu ee ssee eessttaabblelezzccaan n ddeenntrtoro dd ee ll oo ss eessttaatututotos.s . PP AA RR AÁ GG RR AFA OF O 22 °° | Label: EPIGRAFE
# Texto: ne | Label: FECHA
# Texto: iac | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: llaa | Label: FECHA
# Texto: mm | Label: FECHA
# Texto: isis | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: . | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: ne | Label: FECHA
# Texto: iac | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: ieie | Label: FECHA
# Texto: ntn | Label: FECHA
# Texto: 2 | Label: FECHA
# Texto: 2 | Label: FECHA
# Texto: sts | Label: FECHA
# Texto: rt | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: ici | Label: FECHA
# Texto: ic | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: ieie | Label: FECHA
# Texto: ini | Label: FECHA
# Texto: ieie | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: 44 | Label: FECHA
# Texto: logistica | Label: FECHA
# Texto: 55 | Label: FECHA
# Texto: sts | Label: FECHA
# Texto: rt | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: lal | Label: FECHA
# Texto: llaa | Label: FECHA
# Texto: 55 | Label: FECHA
# === spaCy Entities ===
# Texto: 2199 | Label: NUMERO_LEY
# Texto: ( | Label: FECHA
# Texto: m | Label: NUMERO_LEY
# Texto: moo | Label: FECHA
# Texto: 11 | Label: FECHA
# Texto: 99 | Label: FECHA
# Texto: 55 | Label: FECHA
# Texto: 55 | Label: FECHA
# Texto: 22001199 | Label: NUMERO_LEY
# Texto: norma | Label: FECHA
# Texto: norma | Label: FECHA
# Texto: 88 | Label: FECHA
# Texto: .. | Label: FECHA
# Texto: fii | Label: FECHA
# Texto: ict | Label: FECHA
# Texto: iaic : ia: 1 1.. DDiisseenñaar r yy lliiddeerraar r eell ssiisstteemmaa rr ee gg ii oo nn aa l l dd ee s see gg uu rr idid aa d,d , ccoonnvviviveencnicai a yy jj uu ss tit cic iai a pp aa rr aa los municipios que conformen la Región Metropolitana. los municipios que conformen la Region Metropolitana. 2. Liderar la elaboración y puesta en marcha del Plan Integral de Seguridad, 2. Liderar la elaboracion y puesta en marcha del Plan Integral de Seguridad, CC oo nn vv iviv ee nn cic ai a yy JJ uu ss tt icic iaia rr ee gg ioio nn aa l l (( PP ISIS CO J)) , , eenn ccoorrddininaacicoinó n ccoonn ll oo ss PPIISSCOJ Departamental, Distrital y municipales, de acuerdo con población, Departamental, Distrital y municipales, de acuerdo con poblacion, capacidades y necesidades en orden de complementariedad al sistema capacidades y necesidades en orden de complementaried al sistema regional. 3. Diseñar acciones de implementación conjunta y complementaria desde el 3. Disenar acciones de implementacion conjunta y complementaria desde el áammbbitioto rr ee gg ioio nn aa l l ee nn mmaatteeriraia dd ee ccoonnttrrool l dd ee ddeelliittooss yy cc oo mm pp oo rtr at mam ienie ton st os ccoonnttrraariroiso s aa llaa cc oo nn vv ivi ev ne cn iac ,i a, eessttaabbleleccididoso s eenn lla a ll ee yy 11 88 00 11 dd ee 22 00 11 66 , , yy ddeemmaáss nn oo rr mm aa s s qq uu ee lla a mm oo dd ifi if qiq | Label: EPIGRAFE
# Texto: ueu | Label: FECHA
# Texto: ne | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: s. | Label: FECHA
# Texto: 44 | Label: NUMERO_LEY
# Texto: .. | Label: FECHA
# Texto: iei | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: 5 | Label: FECHA
# Texto: cic | Label: FECHA
# Texto: cic | Label: FECHA
# Texto: llaa | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: ic | Label: FECHA
# Texto: n | Label: FECHA
# Texto: n | Label: FECHA
# Texto: coo | Label: FECHA
# Texto: tat | Label: FECHA
# Texto: iei | Label: FECHA
# Texto: ior | Label: FECHA
# Texto: io | Label: FECHA
# Texto: lla | Label: FECHA
# Texto: ioc | Label: FECHA
# === spaCy Entities ===
# Texto: ~ | Label: NUMERO_LEY
# Texto: 99 | Label: FECHA
# Texto: 2199 | Label: FECHA
# Texto: ieie | Label: FECHA
# Texto: nn tat | Label: EPIGRAFE
# Texto: ií | Label: FECHA
# Texto: tt | Label: FECHA
# Texto: foo | Label: FECHA
# Texto: coo | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: sts | Label: FECHA
# Texto: rt | Label: FECHA
# Texto: l | Label: FECHA
# Texto: ií | Label: FECHA
# Texto: ií | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: 33 | Label: FECHA
# Texto: vi | Label: FECHA
# Texto: oió | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: nió | Label: FECHA
# Texto: 44 | Label: FECHA
# Texto: ir | Label: FECHA
# Texto: ncn ic asia , s, aall dd ii ss ee nñ oo , , pp ll aa nn ifi if cic aa cic oi nó n ee ii mm pp lele mm ene tn at ca ioc nió | Label: EPIGRAFE
# Texto: n | Label: FECHA
# Texto: tat | Label: FECHA
# Texto: sio | Label: FECHA
# Texto: s tteerritiotorirailaelse s qq uu ee vv ii nn cc uu lele n n llaa oo ff ee rtr ata rr ee gg ioio nn aa l l yy ll aa dd ee mm aa nn dd a a dd ee I aa ll ii mm ee nn toto s,s , ttaanntoto aa nn ii vv ee l l pp uú bb ll ii cC oO cc oo mm oo pp rr iviv aa dd oo , , dd ee ss aa rr or lo lall na dn od o mmeeccaannisimsmoso s efectivos de articulación comercial convencionales y no convencionales. efectivos de articulacion comercial convencionales y no convencionales. 55 .. RReeaalliizzaarr llaa gg ee ss tit oió nn tt éé cc nn icic aa yy a add mm inin isi ts ratr ta ivt aiv , a, yy llaa vv aa lil did aa cic oi nó n yy aa pp roro bb aca ic onió n pp aa rr aa ll aa cc oo nn ss trt uru cc ic oi nó n yy aa dd ee cc uu aca ic oi nó n dd ee e eqq uu ipip aa mm iei ne tn osto s yy cc ee nn trt ara lel | Label: EPIGRAFE
# Texto: ií | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: ici | Label: FECHA
# Texto: ic | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: 6 | Label: FECHA
# Texto: 6 | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: nió | Label: FECHA
# Texto: n | Label: FECHA
# Texto: ior | Label: FECHA
# Texto: io | Label: FECHA
# Texto: nii | Label: FECHA
# Texto: vv | Label: FECHA
# Texto: oió | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: sio | Label: FECHA
# Texto: s | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: ien | Label: FECHA
# Texto: nie | Label: FECHA
# Texto: ton | Label: FECHA
# Texto: il | Label: FECHA
# Texto: ií | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: nió | Label: FECHA
# Texto: n | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: sio | Label: FECHA
# Texto: s qq uu ee ssee uuttiilliizzaann e enn llaa pp rr oo dd uu cc cic oi nó ,n , eell dd ee ss aa rr oro lloll o dd ee aa cc tt iviv idid aa dd ese s dd ee pp rr oo mm oco ic oi nó , n, vv ee nn tata yy mm ee rr cc aa dd eoe ,o , llaa pp aa rr tit cic ipip aca ic oi nó n dd ee eevveenntotoss dd ee pp rr oo mm oo cic oi nó n yy dd ee ss aa rr oro lloll o Yy, , ttooddaass aa aa qq uu ee ll ala s aa cc tt iviv idid aa ded se s pp rr oo pp iaia ss dd ee ll oo bb jeje toto mm ii ss ioio nn aa l, l, pp aa rr aa gg ee nn ee rara r r bbiieenneesstatra r ssoocciiaal l yy eeccoonnoómmicioc o eenn ll oo ss pp rr oo dd uu cc tot ro er se . s. • EE nn mm aa tet re iar ia dd ee sseerrvviciicosio s pp uú bb licl oic s os dd oo mm icii lc iai rl ioia s rios yy TT II CC : 1 1. . CC oo oo rdrd inin ara , r, pp rr oo mm oo vev re r yy /o/o e ejj ee cc uu tata r r aa cc cc ioio nn ee s s oorriieenntataddasa s aa ll oo gg rara r r uu nn aa aaddeeccuuaaddaa planeación y gestión del recurso hídrico con enfoque regional. planeacion y gestion del recurso hidrico con enfoque regional. 22 .. C Coo oo rr dd inin aa r r yy gg ee ss tit oio nan ra r cc oo nn oo tt rr aa ss aa uu tt oo rir did ada ed se s nn aa cc ioio nn aa lel se s yy // oo tt ee rr rir ti oto riari lea sle s llaa aa ss ee ss oo rir aía yy aa ss ii ss tete nn cic ai a tt éé cc nn icic aa , , aa dd mm inin isi ts ratr tia vt ai va yy ff ii nn aa nn cc iei re ar a yy ll aa aa dd oo pp cc ioi nó n ddee pp rr aá cc tit cic aa s s dd ee bb uu ee nn g goo bb ieie rnrn o o 0o gg oo bb ieie rnrn o o c coo rr pp oo rara tivti ov o eenn llaass e emm pp rr ee ss aa s s pp uú bb lil cic aa s 77 | Label: EPIGRAFE
# === spaCy Entities ===
# Texto: 2 | Label: FECHA
# Texto: 99 | Label: FECHA
# Texto: 2199 | Label: NUMERO_LEY
# Texto: pp | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: ioi | Label: FECHA
# Texto: inn | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: ali | Label: FECHA
# Texto: ut | Label: FECHA
# Texto: ibi | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: ioi | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: 44 | Label: FECHA
# Texto: iei | Label: FECHA
# Texto: ali | Label: FECHA
# Texto: ra | Label: FECHA
# Texto: ior | Label: NUMERO_LEY
# Texto: sio | Label: FECHA
# Texto: s | Label: NUMERO_LEY
# Texto: ioc | Label: FECHA
# Texto: ala | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: 55 | Label: FECHA
# Texto: ií | Label: FECHA
# Texto: ií | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: nió | Label: FECHA
# Texto: n | Label: FECHA
# Texto: it | Label: FECHA
# Texto: nin | Label: FECHA
# Texto: ioió | Label: FECHA
# Texto: 22 | Label: FECHA
# Texto: .. | Label: FECHA
# Texto: vvooccaaccioionnees | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: 33 | Label: FECHA
# Texto: y | Label: FECHA
# Texto: iei | Label: FECHA
# Texto: 55 | Label: FECHA
# Texto: .. | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: ioi | Label: FECHA
# Texto: ini | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: aria | Label: FECHA
# Texto: ior | Label: FECHA
# Texto: sio | Label: FECHA
# Texto: s. | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: ip | Label: FECHA
# Texto: ieie | Label: FECHA
# Texto: ic | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: 99 | Label: FECHA
# Texto: sts | Label: FECHA
# Texto: rt | Label: NUMERO_LEY
# Texto: rt | Label: FECHA
# Texto: rr | Label: NUMERO_LEY
# Texto: ií | Label: FECHA
# Texto: ara | Label: FECHA
# Texto: tété | Label: NUMERO_LEY
# Texto: gig | Label: FECHA
# Texto: 11 | Label: FECHA
# Texto: 00 | Label: FECHA
# Texto: im | Label: NUMERO_LEY
# Texto: rt | Label: NUMERO_LEY
# Texto: ia | Label: FECHA
# Texto: io | Label: FECHA
# Texto: 88 | Label: FECHA
# === spaCy Entities ===
# Texto: 2 | Label: FECHA
# Texto: 2199 | Label: NUMERO_LEY
# Texto: 11 | Label: FECHA
# Texto: ne | Label: FECHA
# Texto: iac | Label: FECHA
# Texto: por | Label: FECHA
# Texto: rir | Label: FECHA
# Texto: 44 | Label: FECHA
# Texto: 00 | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: ip | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: itali nta an a llaa ee jeje cc uu cic oi nó n dd ee ee ss tt uu dd ioio s s dd ee amenaza, vulnerabilidad y riesgo natural y antrópico e identificar y gestionar amenaza, vulnerabilidad y riesgo natural y antropico e identificar y gestionar los proyectos prioritarios para su implementación. los proyectos prioritarios para su implementacion. 33 .. AArrtticicuulalra r llaa ee ss trt uru ctc ut ru ar ca ioc nió | Label: EPIGRAFE
# Texto: n | Label: FECHA
# Texto: ieie | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: tat | Label: FECHA
# Texto: por | Label: FECHA
# Texto: las | Label: FECHA
# Texto: 44 | Label: FECHA
# Texto: .. | Label: FECHA
# Texto: nin | Label: FECHA
# Texto: ir | Label: FECHA
# Texto: ir eenn eell PP ll aa nn DDiirreecctotor r uu nn mmooddeelolo rr ee gg ioio nn aa l l tteerrirtiotoriaril al cc oo nn pp oo lil tí it cic aa s s yy ee ss tt rr aa tete gig ai sa s pp aa rr aa ll aa aa rr tt icic uu lala cic oi nó n dd ee ll oo ss iinnssttrruummenetnosto s dd ee oo rr dd ee nn amam ienie ton to t tee rr rr iti oto rir ai la , l, yy ll oo ss pp rr oo gg rara mm asa s yy pp rr oo yy ee cc tot so s rr ee gg ioio nn ala el se s ee ss trt ara tét gé ig coic so s pp aa rr aa llaa consolidación de los hechos metropolitanos. consolidacion de los hechos metropolitanos. 2. Formular y coordinar conjuntamente, con los municipios y el Distrito, planes, pp rr oo gg rara mm asa , s, pp rr oo yy ee ctc ot so s 0o pp oo lil tí it cic aa s s pp aa rr aa ll aa ffiinnaanncciaiacicoinó n yy pp roro dd ucu cc ioc nió | Label: EPIGRAFE
# Texto: n | Label: FECHA
# Texto: tt | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: nió | Label: FECHA
# Texto: 99 | Label: FECHA
# Texto: 99 | Label: FECHA
# Texto: na | Label: NUMERO_LEY
# Texto: n | Label: FECHA
# Texto: 33 | Label: FECHA
# Texto: .. | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: ip | Label: FECHA
# Texto: ir | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: n | Label: FECHA
# Texto: iac | Label: FECHA
# Texto: ia | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: 44 | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: ip | Label: FECHA
# Texto: ir | Label: FECHA
# Texto: sts | Label: FECHA
# Texto: rt | Label: FECHA
# Texto: itali nta an . a. 55 .. FF oo rr mm uu lala r r yy dd ee ss aa rr or lo lall ra r cc oo nn juju nn tat mam ene ten , te, cc oo nn ll oo ss mm uu nn icic ipi ip oi so s yy eell DD isis trt ir ti ot ,o , pp rr oo gg rar mam asa s dd ee hhaábbitiatat t yy vv ii vv ieie nn dd a a rruurraal l pp rr oo dd uu ctc ivti av a yy ssoosstteennibiblel.e . 9 | Label: EPIGRAFE
# === spaCy Entities ===
# Texto: 2i99 | Label: NUMERO_LEY
# Texto: 2199 | Label: NUMERO_LEY
# Texto: ic | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: . | Label: NUMERO_LEY
# Texto: itl | Label: FECHA
# Texto: tit | Label: FECHA
# Texto: ia | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: ffoorrmmaa | Label: FECHA
# Texto: conjunta | Label: FECHA
# Texto: s | Label: NUMERO_LEY
# Texto: ieie | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: rir | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: rotr | Label: FECHA
# Texto: rmrm | Label: FECHA
# Texto: ini | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: rir | Label: FECHA
# Texto: EEll | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: ip | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: it | Label: FECHA
# Texto: tat | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: 22 | Label: FECHA
# Texto: ne | Label: NUMERO_LEY
# Texto: ibn | Label: FECHA
# Texto: ili | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: rmrm | Label: FECHA
# Texto: ini | Label: FECHA
# Texto: i | Label: FECHA
# Texto: imm | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: aca | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: 33 | Label: FECHA
# Texto: itali | Label: FECHA
# Texto: nta on s os dd ee bb ee nn gg ee nn ee rara r r ee ff ee cc toto ss pp oo ss iti it viv oso s 0o ssoolluuccioionnara r pp rr oo bb lele mm asa s iiddeenntitfiifcicaadodso s ssoobbrree mmaáss dd ee uunnaa dd ee ll aa ss eennttididaaddees s tteerritiotorirailaelse s aassoocciaiaddaass aa llaa RR ee gg ioió nn MM ee tt rr oo pp olo itl ait na an a yy ss uu ss cc oo mm uu nn idid ada ed se . s. 44 . . EEffiiccieinecniac ia ee cc oo non mó im cai .c a. LL oo ss hheecchhooss mm ee trt oro pop lo itali nta on s os ddeebbeenn gg ee nn ee rar ra r bb ee nn ee fif cic ioio s s ee nn llaa aatteennccioiónn cc oo nn juju ntn at ,a , gg ee nn ee rara cic oi nó n dd ee eeccoonnoommiaísa s dd ee ee ss cc aa ll aa Oo dd ee aa gg lolo mm ee rar ca ic oi nó n y/o reducción de costos de implementación, al ser declarados por la Región y/o reduccion de costos de implementacion, al ser declarados por la Region Metropolitana. 1100 | Label: EPIGRAFE
# === spaCy Entities ===
# Texto: 2199 | Label: NUMERO_LEY
# Texto: 5S | Label: FECHA
# Texto: ia | Label: NUMERO_LEY
# Texto: onc | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: sts | Label: FECHA
# Texto: itt | Label: FECHA
# Texto: nal | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: ini | Label: FECHA
# Texto: in | Label: FECHA
# Texto: voti | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: llaa | Label: FECHA
# Texto: iinnssttaanncciai | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: l | Label: FECHA
# Texto: hheecchhoo | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: itali nta an a 0o dd ee ll oo ss mmiieemmbbrorso s dd ee l l CC oo nn ss ee jojo RR ee gg ioio nn ala , l, pp aa rr aa lloo cc uu aa l l dd ee bb ee ccoonntatar r cc oo nn uu nn ddooccuummenetno to ttééccnnicicoo dd ee ss oo pp oo rtr et e qq uu ee cc aa rara ctc et re icr eic e llooss ffeennoómmeennoso s mm ee trt oro pp olo itali nta on s os ddee lala rr ee gg ioió nn , , eessttaabblelezzcac a ll aa ss ii nn tt ee rr dd ee pep ne dn ed ne cin ac si as yy defina las relaciones supramunicipales a que haya lugar, las enmarque en las eessttrruucctuturarsa s tteerritiotorirailaelse s pp ee rtr it ni en ne tn este s - ff ií ss icic oo ee ss pp ee cc iaia l, l, ee cc oo nn oó mm icaic , a, ff uu nn cc ioio nan la l ee iinnssttitiutuccioinoanla l- yy ddeeffininaa ll oo ss oo bb jeje tivti ov so s aa aallccaannzzaar r cc oo nn eell ttrraattaammieineton to dd ee ll hheecchhoo mm ee trt oro pop lo itali nta on . o. EEll ddooccuummenetnot o ttééccnnicicoo dd ee ss oo pp oo rtr et e ii nn cc lulu iri ar á llaa rr uu tata pp aa rr aa ll aa ii mm pp lele mm ene tn acta ioc ni ón dd ee ll oo ss pp ll aa nn ee ss yy pp rr oo gg rara mm asa s qq uu ee ssee pp rr oo pp oo nn ene n pp aa rr aa llaa gg ee ss tit oió nn dd ee l hheecchhoo mm ee trt oro pop lo itali nta on , o, ccoonn ssuuss pp lala zz oo ss cc oo rr rere sps op no dn ied nie ten | Label: EPIGRAFE
# Texto: st | Label: FECHA
# Texto: 44 | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: EEll | Label: FECHA
# Texto: ibi | Label: FECHA
# Texto: lb | Label: FECHA
# Texto: ten | Label: FECHA
# Texto: ste | Label: FECHA
# Texto: socioeconómica y otro de ordenamiento físico - espacial. planeacion socioeconomica y otro de ordenamiento fisico espacial. EE ll PP lala nn EE ss trtr aa tété gig | Label: EPIGRAFE
# Texto: itali | Label: FECHA
# Texto: nta | Label: FECHA
# Texto: iei | Label: FECHA
# Texto: l | Label: FECHA
# Texto: tteerrirtiotroiori | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: nió | Label: FECHA
# Texto: n | Label: FECHA
# Texto: nta | Label: FECHA
# Texto: osn | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: ici | Label: FECHA
# Texto: ic | Label: FECHA
# Texto: ifii | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: nió | Label: FECHA
# Texto: ; | Label: FECHA
# Texto: n | Label: FECHA
# Texto: n | Label: FECHA
# Texto: tata eenn ll oo ss pp ll aa nn ee ss dd ee ddeessaarrorlololl.o . LL aa SS ee cc rere tata riarí a TT éé cc nn icic aa dd ee ll aa RR ee gg ioió nn MIV ele trt or po op lio tali nta an a BB oo gg oo tat á =- CCuunnddininamamaracarc a pp rr ee ss tata rará dd ee ff oo rr mm aa gg rr aa tutu itait a aa ss ee ss oo rr iaía yy aa pp oo yy oo tt éé cc nn icic o,o , jj uu rir díd ici oc o yy ff inin aa nn cic ei re or , o, aa llooss mm uu nn icic ipi ip oi so s qq uu ee ll oo ss oo lil cic iti ete n,n , pp aa rr aa ll aa aa cc tutu aa lizli az ca ioc nió | Label: EPIGRAFE
# Texto: n | Label: FECHA
# Texto: izi | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: nió | Label: FECHA
# Texto: ici | Label: FECHA
# Texto: ic | Label: FECHA
# Texto: ° | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: lal | Label: FECHA
# Texto: por | Label: FECHA
# Texto: ieie | Label: FECHA
# Texto: llaa | Label: FECHA
# Texto: por | Label: FECHA
# === spaCy Entities ===
# Texto: 21 | Label: NUMERO_LEY
# Texto: .. | Label: NUMERO_LEY
# Texto: 99 | Label: FECHA
# Texto: 2199 | Label: NUMERO_LEY
# Texto: itl | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: 15 | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: ara | Label: FECHA
# Texto: tété | Label: NUMERO_LEY
# Texto: gig | Label: FECHA
# Texto: ieie | Label: FECHA
# Texto: tet | Label: FECHA
# Texto: ioió | Label: FECHA
# Texto: ioió | Label: FECHA
# Texto: vi | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: coo | Label: FECHA
# Texto: 22 | Label: FECHA
# Texto: .. | Label: FECHA
# Texto: nin | Label: FECHA
# Texto: ici | Label: NUMERO_LEY
# Texto: vi | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: l. | Label: FECHA
# Texto: 33 | Label: FECHA
# Texto: nin | Label: FECHA
# Texto: ici | Label: NUMERO_LEY
# Texto: ieie | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: 44 | Label: FECHA
# Texto: .. | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: izt aiz ra r eell ss ee gg uu imim iei ne tn o to yy ee vv aa lulu aa cic oi nó n dd ee l c cuu mm pp lil mim iei ne tn o to dd ee lloo eessttaabblelecicdiod o eenn eell PP ll aa nn EE ss trt ara tét gé ig coic o dd ee llaa RR ee gg ioió nn MM ee trt oro pp olo itl ait na an , a, la Región Metropolitana deberá constituir un sistema de información, la Region Metropolitana debera constituir un sistema de informacion, ss ee gg uu imim iei ne tn o to yy eevvaaluluaaccioión n aa tt rr aa vv éé ss dd ee ll OObbsseervrvaatotroior io dd ee DDiinnaámmicicaas s MM ee trt oro pop lo itali nta an s as y Regionales. ARTÍCULO 16°. COMPONENTE DE ORDENAMIENTO FÍSICO - ESPACIAL ARTICULO 16°. COMPONENTE DE ORDENAMIENTO FISICO ESPACIAL DEL PLAN ESTRATÉGICO Y DE ORDENAMIENTO DE LA REGIÓN DEL PLAN ESTRATÉGICO Y DE ORDENAMIENTO DE LA REGION MM EE TT RR OO POP LO ITL AI NT AA . NA. EE nn ssuu cc oo mm pp oo nen ne tn e te dd ee oo rr dd ee nn amam ienie ton to ffiíssiiccoo -- ee ss pp aa cc iaia l, l, eell PP ll aa nn EE ss trt ara tété | Label: EPIGRAFE
# Texto: gig | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: mlm | Label: FECHA
# Texto: ene | Label: FECHA
# Texto: ten | Label: FECHA
# Texto: 22 | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: 44 | Label: FECHA
# Texto: .. | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: tut | Label: FECHA
# Texto: ru | Label: FECHA
# Texto: 55 | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: oió | Label: FECHA
# Texto: .o | Label: FECHA
# Texto: 66 | Label: FECHA
# Texto: ata | Label: FECHA
# Texto: tivti | Label: FECHA
# Texto: fif | Label: FECHA
# Texto: ci | Label: FECHA
# Texto: ic | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: ip | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: 1122 | Label: FECHA
# === spaCy Entities ===
# Texto: 2i | Label: NUMERO_LEY
# Texto: 99 | Label: FECHA
# Texto: 2199 | Label: NUMERO_LEY
# Texto: tteerritiotoriarila | Label: FECHA
# Texto: itali | Label: FECHA
# Texto: nta on s,o s, dd ee aaccuueerdrdoo cc oo nn lloo pp rr ee vv isi ts ot o ee nn llaa pp rr ee ss ee nn tet e ll ee yy . 88.. LLaass pp oo lil tí it cic aa s s pp aa rr aa llaa pp rr oo tete cc cic oi nó n dd ee ll oo ss ss uu ee lolo ss dd ee vv aa lolo r r aa gg rr oo pp ee cuc au ra ior io yy ff oo rr ee ss tat la . l. 99 | Label: EPIGRAFE
# Texto: EEll | Label: FECHA
# Texto: ioi | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: 11 | Label: FECHA
# Texto: 17 | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: rir | Label: FECHA
# Texto: ne | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: itali nta an a eenn rr ee lala cc ioió nn cc oo nn ll oo ss ss igig uu ieie ntn et se s aa ss pp ee cc tot so :s : 11 .. AArrmmoonnizizacaicoinó n dd ee pp oo lil tí it cic aa s s dd ee oo cc uu pp aa cic oi nó n yy pp rr oo tete cc ic oi nó n dd ee ll aa EE ss tt rr uu cc tutu rar a EE cc oo loló gg icic aa PP rr ii nn cc ipip aa lRl eR ge iog nio an l al aa pp aa rr tit ri r dd ee uu nn aa vv isis ioió nn rr ee gg ioio nn ala . l. 22 .. DDeeffininicicioión n dd ee ll aa ss ii nn ff rr aa ee sts rutr cu tuc rt au sr as vv iaia l l yy dd ee tt rr aa nn ss pp oro tert , e, ss ee rr vv icic ioio s s pp uú bb lil cic oo s (( aa gg uu aa , , ee nn ee rr gg iaía , , ssaanneeaammieinetno to bb aá ss icic oo , , mm aa nn ee joj o dd ee rr ee sS idid uu oso )s ) yy ee qq uu ipip aa mm iei ne ton st os de escala regional. 33.. AA rr tit cic uu lal ca ic oi nó n dd ee pp oo lil tí it cic aa s s dd ee gg ee ss tit oió nn dd ee ll rr ii ee ss gg oo yy aa dd aa pp tat ca ic oi nó n aall ccaammbbioio climático. climatico. 44 .. AA rr tit cic uu lal ca ic oi nó n ddee pp oo lil tí it cic aa s s yy pp rr oo gg rara mm asa s dd ee vviivvieienndda.a . CAPÍTULO V CAPITULO V ESTRUCTURA ADMINISTRATIVA Y SISTEMA DE TOMA DE DECISIONES AA RR TT ICÍ UC LU OL O 11 88 °.° , CC OO NN SS EE JOJO RR EE GG IOIO NAN LA . L. EEll CC oo nn ss ee jojo RR ee gg ioio nn aa l l ss ee rr aá eell mm aá xx imim oo órgano de gobierno de la Región Metropolitana Bogotá - Cundinamarca y estará organo de gobierno de la Region Metropolitana Bogota Cundinamarca y estara cc oo nn fofo rmrm ada od o pp oo r r ee ll AA lclc aa ldld ee MM aa yy oo r r dd ee BB oo gg oo tatá , , ll oo ss AAllccaaldldeess dd ee ll oo ss mm uu nn icic ipip ioi so s dd ee CC uu nn dd inin aa mm ara cr ac a qq uu ee ssee aa ss oo cc ieie nn yy ee l l GG oo bb ee rnrn ada od ro r dd ee CC uu nn dd inin amam ara carc . a. PP AA RR AÁ GG RR AFA OF O 11 °° | Label: EPIGRAFE
# Texto: nniivveel | Label: FECHA
# Texto: ieie | Label: FECHA
# Texto: it | Label: FECHA
# Texto: nen | Label: FECHA
# Texto: ne | Label: FECHA
# Texto: l | Label: FECHA
# Texto: ccoonn | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: ieie | Label: FECHA
# Texto: it | Label: FECHA
# Texto: nen | Label: FECHA
# Texto: ne | Label: FECHA
# Texto: eenn | Label: FECHA
# Texto: 3 | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: it | Label: FECHA
# Texto: nen | Label: FECHA
# Texto: ne | Label: NUMERO_LEY
# Texto: ten | Label: FECHA
# Texto: te | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: iri | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: n | Label: FECHA
# Texto: 0o | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: itali nta an , a, Oo llaa tteerrcceerara pp aa rtr ete dd ee ssuuss mmiieemmbbroros.s . 1133 | Label: EPIGRAFE
# === spaCy Entities ===
# Texto: 2199 | Label: NUMERO_LEY
# Texto: 2200 | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: los miembros del Consejo Regional, el DDiirreecctotor r dd ee llaa RR ee gg ioió nn MM ee tt rr oo pp oo litl ait na an a 0o ll aa tteerrcceerara pp aa rr tete dd ee ll oo ss mmiieemmbbroros s dd ee ll aa ss corporaciones de los entes territoriales que la integran, yen la iniciativa popular, corporaciones de los entes territoriales que la integran, y en la iniciativa popular, dd ee ccoonnffoormrmidiadda d cc oo nn eell aa rr tt icíc uu lol o 11 55 55 dd ee llaa CCoonnsstittiutucicoinó n PP oo lil tí it cic aa , , eenn lloo rreellaaccioionnaadod o cc oo nn eell cc ee nn ss oo eelleecctotoraral. l. EEll DDiirreecctotor r dd ee llaa RR ee gg ioió nn MM ee trt oro pp olo italit na an a ddeebbeerará pp rr ee ss ee nn tat ra r ll oo ss pp rr oo yy ee ctc ot so s dd ee ddeeccisisioionnees s MM ee tt rr oo pp oo litl ait na an sa s qq uu ee cc oo rr rere ss pp ono dn ad na n aa ll PP ll aa nn ee ss trt ara tét gé ig coic o yy dd ee oo rr dd ee nn aa mm ienie ton to mm ee trt oro pp olo itali nta on , o, ll oo ss pp ll aa nn ee ss dd ee inin vv ee rsr is oi nó ,n , pp rr ee ss uu pp ueu se ts ot o aannuuaal l dd ee rentas y gastos, estructura administrativa y planta de cargos. AA RR TT ICÍC ULU OL O 22 11 ° | Label: EPIGRAFE
# Texto: itali | Label: FECHA
# Texto: nta on ; o; dd ee recursos naturales, manejo y conservación del ambiente; de transporte; fiscal y recursos naturales, manejo y conservacion del ambiente; de transporte; fiscal y aa dd mm inin isi ts ratr ta ivt aiv , a, ee nn ll oo ss ss ii gg uu ieie nn tet se s ttéérrmmininoos:s : 11 .. EE nn mm aa tete rir ai a dd ee pp ll aa nn ifi if cic aa cic oi nó n dd ee l l ddeessaarrorolloll o aa rr mm oó nn ici oc ,o , ii nn tt ee gg rara l l yy ssuusstteenntatablbel e dd ee l tteerritiotoriori:o : a) Declarar los Hechos Metropolitanos bb )) AA dd oo pp tat ra r eell PP ll aa nn EE ss trt ara tété | Label: EPIGRAFE
# Texto: gig | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: Establecer | Label: FECHA
# Texto: las | Label: FECHA
# Texto: Establecer | Label: FECHA
# Texto: las | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: it | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: nió | Label: FECHA
# Texto: llaa | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: ali | Label: FECHA
# Texto: ra | Label: FECHA
# Texto: ior | Label: FECHA
# Texto: sio | Label: FECHA
# Texto: s pp aa rr aa ll aa gg ee ss tit oió n n dd ee l l ss uu ee lolo eenn ll oo ss mm uu nn icic ipi ip oi so s dd ee ssuu jj uu rr isis dd ici cc ic oi nó . n. ee )) AAuuttoorirziazra r ll aa ss uu ss cc rir pip cic oi nó n dd ee ccoonnvveennioiso s Oo ccoonntrtaratotso s pp ll aa nn . gg )) AA ss ee ss oo rara r r ll aa ii mm pp lele mm ene tn acta ioc ni ón dd ee ll cc aa tt aa ss trt oro mm uu ltl it pip ror po op só its oi to eenn ll oo ss mm uu nn icic ipi ip oi so s qq uu ee ii nn gg rr ee ss ee nn aa ll aa RR ee gg ioió nn MM ee trtr oo pp olo itl ait na an a eenn uu nn pp ll aa zz oo nn oo mm aa yy oo r r aa tt rr ee ss aa nñ oo ss , contados a partir de su fecha de ingreso. Si en el momento de su ingreso a la RR ee gg ioió nn MM ee trt oro pp olo italit na an a eell mm uu nn ici ic pi ip oi o 0o DDiisstrtirtioto nnoo ttuuvvieierara ssuu ccaattaasstrtoro aa cc tutu aa lizli az da od , o, dd ee bb ee rará cc oo mm pp ror mom ete ert se er se aa ssuu aaccttuuaalilzizaacicoinó.n . EE nn uunn pp ll aa zz oo nnoo mm aa yy oo r aa tt rr ee ss (( 33 ) ) aa nñ oo ss UU nn aa vv ee zz cc uu mm pp lidli od o eessttee pp lala zz oo , , aa qq uu ee llollo s s mm uu nn ici ic pi ip oi so s cc uu yy oo ccaattaasstrtoro ee ss tété dd ee ss aa cc tutu ala izli az da od o nnoo pp oO dd rará nn sseerr oo bb jeje tot o dd ee ii nn vv ee rsrs ioi nó n dd irir ee cc tat a dd ee ll aa RR ee gg ioió nn MM ee trt oro pp olo italit na an , a, ss aa lvlv oo qq uu ee dd ee ff oo rr mm aa uunnaánnimimee ee ll CC oo nn ss ee jojo RR ee gg ioio nn aa l considere que se trate de un proyecto de inversión estratégica indispensable considere que se trate de un proyecto de inversion estratégica indispensable pp aa rr aa eell ddeessaarrorolloll o dd ee llaa RR ee gg ioió nn . 22 .. EE nn mmaateteriraia dd ee rr aa cc ioio nn aa lizli az ca ioc nió | Label: EPIGRAFE
# Texto: n | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: ziz | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: nió | Label: FECHA
# Texto: n | Label: NUMERO_LEY
# Texto: eenn | Label: FECHA
# Texto: ) | Label: NUMERO_LEY
# Texto: it | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: nió | Label: FECHA
# Texto: llaa | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: ií | Label: FECHA
# Texto: 1144 | Label: FECHA
# === spaCy Entities ===
# Texto: 2199 | Label: NUMERO_LEY
# Texto: 33 | Label: FECHA
# Texto: itali | Label: FECHA
# Texto: nta on : o: aa )) DDeecclalararar r dd ee uuttiilildidaadd pp uú bb lil cic aa 0o dd ee iinntteerrééss ss oo cc iaia l l aa qq uu ee ll olo s s iinnmmuueebbleles s nneecceessaariroios s pp aa rr aa aatteennddeer r llaass nneecceessididaaddese s pp rr ee vv isis tat sa s eenn eell PPllaann EE ss trt ara tét gé ig coic o dd ee llaa Región Metropolitana Region Metropolitana bb )) PP lala nn ifi if ci ac ra , r, cc oo oo rdrd inin ara r yy gg ee ss tit oio nan ra r ll aa ccoonnsstrturuccicoinó n dd ee oo bb rr aa ss dd ee ccaarraáccteter r metropolitano. cc )) DDeeccreretatar r eell cc oo bb roro ddee llaa pp aa rr tt icic ipip aca ic oi nó n eenn pp ll uu ss vv aa lil aía pp oo r r oobbrraa pp uú bb liclic aa 0o llaa cc oo nn trt ir bib ucu ioc nió | Label: EPIGRAFE
# Texto: n | Label: FECHA
# Texto: llaa | Label: FECHA
# Texto: 44 | Label: FECHA
# Texto: .. | Label: NUMERO_LEY
# Texto: s | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: itali nta o no dd ee ccoonnffoormrmidiadda d ccoonn ll oo ee ss tt aa bb lele cic di od o ee nn eell PPllaann EE ss trt ara tét gé ig coic o dd ee llaa RR ee gg ioió nn M Mee tt rr oo pp oo litl ait na an a yy ll oo ss pp ll aa nn ee ss yy pp rr oo gg rara mm asa s qq uu ee ll oo ddeessaarrorollellne n 0o cc oo mm pp lel mem ene | Label: EPIGRAFE
# Texto: ten | Label: FECHA
# Texto: .e | Label: FECHA
# Texto: 5 | Label: FECHA
# Texto: itali | Label: FECHA
# Texto: nta | Label: FECHA
# Texto: if | Label: NUMERO_LEY
# Texto: ioc | Label: FECHA
# Texto: nió | Label: FECHA
# Texto: n | Label: NUMERO_LEY
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: itali nta an . a. bb )) EE jj ee rr cc ee r r llaa ffuunnccioiónn dd ee aauuttoorirdidada d mm ee trt oro pop lo itali nta an a dd ee tt rr aa nn sps op ro ter te pp uú bb lil cic oo . cc )) FF ii jaja r r ll aa ss tt aa rr ifi afa s s dd ee l l sseerrvvicicioio dd ee t trr aa nn ss pp oo rtert e pp uú bb lil cic oo dd ee aaccuueerdrdoo cc oo nn ssuu competencia. dd )) FF oo rr mm uu lal ra r yy aa dd oo pp tata r r iinnssttrruummenetnosto s pp aa rr aa llaa pp lala nn ifi icfi ac ca ioc nió | Label: EPIGRAFE
# Texto: n | Label: FECHA
# Texto: ) | Label: FECHA
# Texto: ne | Label: FECHA
# Texto: iac | Label: FECHA
# Texto: tet | Label: FECHA
# Texto: 6 | Label: FECHA
# Texto: materia | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: iei | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: ip | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: izi | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: nió | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: rt ir e ell ii nn gg rr ee ss oo dd ee mm uu nn icic ipi ip oi so s dd ee l l dd ee pp aa rtr at mam ene ton to ddee CCuunnddininamamaracarc a aa llaa Región Metropolitana. Region Metropolitana. 1155 | Label: EPIGRAFE
# === spaCy Entities ===
# Texto: 2i99 | Label: NUMERO_LEY
# Texto: 2199 | Label: NUMERO_LEY
# Texto: itl | Label: FECHA
# Texto: coo | Label: FECHA
# Texto: ií | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: itali | Label: FECHA
# Texto: nta on o pp aa rr aa nn ee gg oo cc iai ra r ee mm pp réré sts | Label: EPIGRAFE
# Texto: itt | Label: FECHA
# Texto: ara | Label: FECHA
# Texto: ) | Label: NUMERO_LEY
# Texto: ioc | Label: FECHA
# Texto: nió | Label: FECHA
# Texto: n | Label: FECHA
# Texto: oro | Label: FECHA
# Texto: pop | Label: FECHA
# Texto: itali nta an a yy llaass ffuunnccioionnese s dd ee ss uu ss dd ee pp ee nn ded ne cn iac sia . s. f f)) CC rr ee aa r r yy oo rr gg aa nn izi az ra r ll aa ss UUnniiddaaddeess TTééccnnicicaass ii nn dd isis pp ee nn sas ba leb sle s pp aa rr aa eell cumplimiento de los objetivos y funciones de la Región Metropolitana. cumplimiento de los objetivos y funciones de la Region Metropolitana. gg )) AA dd oo pp tata r r yy mm oo dd ifi if ci ac ra r ll oo ss EEssttaatututotos s dd ee llaa RR ee gg ioió nn MM ee trt oro pp olo italit na an . a. h) Aprobar la planta de personal al servicio de la Región Metropolitana, así h) Aprobar la planta de personal al servicio de la Region Metropolitana, asi cc oo mm oo ll aa ss eessccaalalass dd ee rr ee mm uu nen re ar ca ioc nió | Label: EPIGRAFE
# Texto: n | Label: FECHA
# Texto: nie | Label: FECHA
# Texto: ten | Label: FECHA
# Texto: st | Label: FECHA
# Texto: nen | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: nió | Label: FECHA
# Texto: n | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: izi | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: nió | Label: FECHA
# Texto: n | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: ntn | Label: FECHA
# Texto: n | Label: FECHA
# Texto: iei | Label: FECHA
# Texto: ffuunnccioionnees | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: ait | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: itali | Label: FECHA
# Texto: nta on o llaa dd ee lele gg aa cic oi nó n dd ee ss uu ss cc oo mm pp ee tet ne cn iac sia . s. pp )) DD ee ff inin iri r ll oo ss aa pp oo rtr ete s s dd ee lolo ss ee nn tete ss tteerritiotorirailaelse s aassoocciaiaddoos s aa ll aa RR ee gg ioió nn Metropolitana. qq )) DD aa rr ss ee ssuu pp rr oo pp ioio rr ee gg lala mm ene tn ot . o. 88 .. LL aa ss dd ee mm aá ss qq uu ee llee aa ss igig nn ee llaa ll ee yy 0o ssee llee dd ee lele gg uu ee n n ccoonnfoformrme e aa ee ss tata . PP AA RR AÁ GG RR AFA OF O PP RR IMIM EE ROR .O . LL aa ss ddeeccisisioionnees s rreeffeerreenntetse s aa ll oo ss aa pp oo rr tete s,s , gg aa ss toto s s yy ll aa ss iinnvveerrssioionnese s dd ee ll aa RR ee gg ioió nn MM ee tt rr oo pp olo itl ait na an a rr ee qq uu ieie rer ne n llaa aa cc ee pp tata cic oi nó n dd ee l l AAllccaaldldee MM aa yy oo r de Bogotá y el Gobernador de Cundinamarca. de Bogota y el Gobernador de Cundinamarca. PP AA RR AÁ GG RR AFA OF O SSEEGGUUNNDDO.O . LL oo ss EE ss tt aa tutu toto s s dd ee ll aa RR ee gg ioió nn MM ee tt rr oo pp olo itl ait na an a BB oo gg oo tatá - ­ CC uu nn dd inin amam ara carc a pp oO dd rará nn ddeeffininiri r oottrraass aattrriibbuuccioinoense s qq uu ee ssee ccoonnssidideerer e ddeebbaa aa ss uu mm iri ,r , ddeenntrtoro dd ee ll oo ss ll ií mm iti ete s s dd ee llaa CC oo nn ss tit ti utu cic oi nó yn y llaa ll ee yy . AARRTTICÍCULUOL O 22°.° , SSIISSTTEEMMA A DD EE TTOOMMAA DD EE DD EE CC ISI IS OI NO EN S ES DDEENNTTRROO DD EE LL CCOONNSSEEJOJO RREEGGIOIONNALA. L. EEll CC oo nn ss ee jojo RR ee gg ioio nn aa l l tt oo mm aa rar á ssuuss dd ee cc isis ioio nn ee s s dd ee aa cc uu ee rdrd oo cc oo nn ll oo ss ss ii gg uu ieie nn tet se s ccrriitteeriroios:s : 11 .. EEnn ll aa ss ddeeccisisioionnees s dd ee ll CC oo nn ss ee jojo RR ee gg ioio nn aa l l ssee pp rr oo mm oo vev re ar á ee ll cc oo nn ss ee nn ss oo , , tt aa l l cc oo mm oo lloo eessttaabbleleccee ee ll aarrttiíccuulolo 33 22 55 dd ee lala CC oo nn ss tit ti ut cu ic oi nó . n. 1166 | Label: EPIGRAFE
# === spaCy Entities ===
# Texto: 2i99 | Label: NUMERO_LEY
# Texto: 2199 | Label: NUMERO_LEY
# Texto: 2 | Label: FECHA
# Texto: por | Label: FECHA
# Texto: los | Label: FECHA
# Texto: tematica | Label: FECHA
# Texto: 1 | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: por | Label: FECHA
# Texto: veces | Label: FECHA
# Texto: 1 | Label: FECHA
# Texto: por | Label: FECHA
# Texto: veces | Label: FECHA
# Texto: 2 | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: los | Label: FECHA
# Texto: los | Label: FECHA
# Texto: 3 | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: 23 | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: 23 | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: oo | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: 24 | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: 24 | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: tener | Label: FECHA
# Texto: las | Label: FECHA
# Texto: tener | Label: FECHA
# Texto: 1177 | Label: FECHA
# === spaCy Entities ===
# Texto: 2.:.99 | Label: FECHA
# Texto: 2199 | Label: NUMERO_LEY
# Texto: aá | Label: FECHA
# Texto: 11 | Label: FECHA
# Texto: iri | Label: FECHA
# Texto: ara | Label: FECHA
# Texto: ntn | Label: FECHA
# Texto: itl | Label: FECHA
# Texto: n | Label: FECHA
# Texto: rir | Label: FECHA
# Texto: ti | Label: FECHA
# Texto: 25 | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: 1 | Label: FECHA
# Texto: sea | Label: FECHA
# Texto: 0 | Label: FECHA
# Texto: ir | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: nniivveel | Label: FECHA
# Texto: eell | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: ioió nn . 22 .. TT aa mm pp oco oc o pp oO dd rará sseerr ee ll ee gg idid oo qq uu ieie nn h haa yy aa ss ii dd oo ccoonnddeennaadod o aa pp ee nn aa dd ee pp rr isis ioió nn pp oo rr dd ee lil ti oto ss ccoommuunnees.s . 33 .. QQ uu ieie nn dd ee nn trt or o dd ee l l aa nñ oo ii nn mm ee dd iai ta at ma em ne ten te aannteteriroiro r aa llaa eelleeccioiónn hh aa yy aa iinntteervrveenindiod o ee nn ll aa gg ee ss tit oió nn dd ee nn ee gg oo cc ioio s s aa nn tt ee eennttididaaddees s pp uú bb lil cic aa s s aa nn ii vv ee l l dd ee l l DDiisstrtirtioto CC aa pp iti ata l,l , dd ee l l dd ee pp aa rtr at ma em ne ton , to, 0o ll oo ss mm uu nn ici ic pi ip oi so s aassoocciaiaddooss 0o ee nn llaa cc ee lele bb rara cic oi nó n dd ee cc oo nn trt ara tot so s cc oo nn eennttididaaddese s pp uú bb lil cic aa s s dd ee cc uu aa lqlq uu iei re r nn ii vv ee l l eenn iinntteerrééss pp rr oo pp ioio 0o dd ee tt ee rr cc ee ror so ,s , ss ieie mm pp rer e qq uu ee ll oo ss ccoonntrtaratotso s ddeebbaann ee jj ee cc uu tata rsr es e Oo cc uu mm pp lil ri sr es e ee nn ee ll aá rr ee aa dd ee jj uu rir sis dd ici cc ioc nió | Label: EPIGRAFE
# Texto: n | Label: FECHA
# Texto: ií | Label: FECHA
# Texto: mm | Label: FECHA
# Texto: isis | Label: FECHA
# Texto: ten | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: trt | Label: FECHA
# Texto: ir | Label: FECHA
# Texto: por | Label: FECHA
# Texto: vinculo | Label: FECHA
# ...
# Texto: uú | Label: FECHA
# Texto: ig | Label: FECHA
# Texto: 44 | Label: NUMERO_LEY
# Texto: ° | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: VVaalildidacaiocnió | Label: FECHA
# Texto: s.l | Label: FECHA
# Texto: mmaarcrcoo | Label: FECHA
# Texto: vvaalildidaar | Label: FECHA
# Texto: r | Label: FECHA
# Texto: práctica | Label: FECHA
# Texto: practica | Label: FECHA
# Texto: nin | Label: FECHA
# Texto: 44 | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: n | Label: FECHA
# Texto: iei | Label: FECHA
# Texto: mim | Label: FECHA
# Texto: ienie | Label: FECHA
# Texto: AArrtitcíuclou | Label: FECHA
# Texto: lo | Label: NUMERO_LEY
# Texto: 55 | Label: NUMERO_LEY
# Texto: ° | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: gr | Label: FECHA
# Texto: ir | Label: FECHA
# Texto: ti | Label: FECHA
# Texto: s especiales y municipios de categorías 1, 2 Y 3 podrán mejorar, crear y/o equipar especiales y municipios de categorias 1, 2 y 3 podran mejorar, crear ylo equipar los quirófanos en universidades públicas que estén en su jurisdicción para apoyar los quirofanos en universidades publicas que estén en su jurisdiccion para apoyar llaa ii mm pp lele mm ene tn acta ioc ni ón dd ee l l PP rr oo gg rara mm a a eenn ssuuss t tee rr rr iti oto rir oio s,s , ee ss toto dd ee aaccuueerdrdo o ccoonn ssuu dd ii ss pp oo nn ibi ib lidil aid da d pp rr ee ss uu pp ueu se tas lt al yy bb aa jojo ll oo ss ll ii nn ee aa mm iei ne tn osto s dd ee l l PP rr oo gg rara mm a a NN aa cc ioio nn aa l l dd ee EEsstteerirliizliazcaiocnió n QQ uu iri urú rgr ig ci ac a dd ee GG aa toto ss yy PP ee rr rr oo ss . AArrtitcíuclou lo 11 66 ° | Label: EPIGRAFE
# Texto: ° | Label: FECHA
# Texto: ara | Label: FECHA
# === spaCy Entities ===
# Texto: 2374 | Label: FECHA
# Texto: -- | Label: FECHA
# Texto: 12 | Label: FECHA
# Texto: 00 | Label: FECHA
# === spaCy Entities ===
# Texto: 237t1 | Label: NUMERO_LEY
# Texto: 2374 | Label: NUMERO_LEY
# Texto: HHoojjaa | Label: FECHA
# Texto: 22 | Label: NUMERO_LEY
# Texto: ~ | Label: FECHA
# Texto: i | Label: FECHA
# Texto: ' | Label: FECHA
# Metadatos guardados en: c:/Users/Jorge/OneDrive/Documents/proyect/document/json_output_2024\LEY-2374-2024.json
# === spaCy Entities ===
# Texto: 2375 | Label: FECHA
# Texto: " | Label: FECHA
# Texto: EEll | Label: FECHA
# Texto: ccoonntrtraa | Label: FECHA
# Texto: ddee | Label: FECHA
# Texto: 22001199 | Label: NUMERO_LEY
# Texto: ií | Label: FECHA
# Texto: mm | Label: FECHA
# Texto: o0 | Label: FECHA
# Texto: 221199CC | Label: FECHA
# Texto: 00 | Label: FECHA
# Texto: 00 | Label: FECHA
# Texto: llaa | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: serán | Label: FECHA
# Texto: inhabilitadas | Label: FECHA
# Texto: seran | Label: FECHA
# Texto: iinnhhaabbiliidliadda | Label: FECHA
# Texto: ffaalloo | Label: FECHA
# Texto: tatá ndn od so es e aa ll oo ss lliímmitietes s tt ee mm pp oo rar la el se s ee ss tt aa bb lele cic di od so s eenn eell ii nn cc isis oo pp rr imim ee ror o dd ee ll aa rr tt icíc uu lol o 55 11 dd ee ll aa pp rr ee ss ee ntn et e ll ee yy , , llaa cc uu aa l l ee mm pp ee zaz ra ar á aa ccoonntatarsres e uunnaa vveezz ssee cc uu mm pp lala ll aa pp ee nn aa pp rr ii nn cc ipip ala . l. AA RR TT ICíC ULU OL O 33 o0 . . AAddicicioiónnesees e eell aarrtticícuulol o 22 ° | Label: EPIGRAFE
# Texto: ° | Label: FECHA
# Texto: 11991188 | Label: FECHA
# Texto: 00 | Label: FECHA
# Texto: 11 | Label: FECHA
# Texto: llaa | Label: FECHA
# Texto: llaa | Label: FECHA
# Texto: l | Label: NUMERO_LEY
# Texto: lii | Label: FECHA
# Texto: ara | Label: FECHA
# Texto: l | Label: FECHA
# Texto: interacción | Label: FECHA
# Texto: ici | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: ieie | Label: FECHA
# Texto: tat | Label: FECHA
# Texto: l | Label: FECHA
# Texto: .r | Label: FECHA
# Texto: ) | Label: FECHA
# Texto: 22 | Label: FECHA
# Texto: .. | Label: FECHA
# Texto: vii | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: ioió nn dd ii rr ee cc tata qq uu ee ss uu pp uú bh lil ci oc o oo bb jeje tit vi ov o sseeaann nn ii | Label: EPIGRAFE
# Texto: ii | Label: FECHA
# Texto: trt | Label: FECHA
# Texto: ere | Label: FECHA
# Texto: ll | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: it | Label: FECHA
# Texto: trt oro s s ddee dd ii vv ee rsr is oi no en se ).s ). I | Label: EPIGRAFE
# === spaCy Entities ===
# Texto: 2375 | Label: NUMERO_LEY
# Texto: 1 | Label: FECHA
# Texto: 2375 | Label: NUMERO_LEY
# Texto: 44 | Label: FECHA
# Texto: .. | Label: FECHA
# Texto: raa | Label: FECHA
# Texto: iti | Label: FECHA
# Texto: 55 | Label: FECHA
# Texto: ior | Label: NUMERO_LEY
# Texto: sio | Label: FECHA
# Texto: s | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: .. | Label: NUMERO_LEY
# Texto: ieie | Label: FECHA
# Texto: tt | Label: FECHA
# Texto: it | Label: FECHA
# Texto: vi | Label: FECHA
# Texto: 99 | Label: FECHA
# Texto: iri ir ti ut au la el se s yy ddeemmaáss f foo rr mm aa ss dd ee aauuttoorrididaad d ee ss pp iri ir ti utu ala l Oo tt ee oo loló gg ici ac .a . 11 00 | Label: EPIGRAFE
# Texto: coo | Label: FECHA
# Texto: 11 | Label: FECHA
# Texto: 11 | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: st | Label: FECHA
# Texto: 12 | Label: FECHA
# Texto: 1133 | Label: FECHA
# Texto: rara | Label: FECHA
# Texto: nan | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: 1 | Label: FECHA
# Texto: 155 | Label: FECHA
# Texto: st | Label: FECHA
# Texto: coo | Label: FECHA
# Texto: mim | Label: FECHA
# Texto: ienie | Label: FECHA
# Texto: iei | Label: FECHA
# Texto: respectiva | Label: FECHA
# Texto: la | Label: FECHA
# Texto: iac | Label: FECHA
# Texto: .i | Label: FECHA
# Texto: la | Label: FECHA
# Texto: 11 | Label: FECHA
# Texto: 99 | Label: FECHA
# Texto: llaa | Label: FECHA
# Texto: 22 | Label: FECHA
# Texto: 00 | Label: FECHA
# Texto: eenn | Label: FECHA
# Texto: 22 | Label: FECHA
# Texto: 11 | Label: FECHA
# Texto: hhaabbitituuaal | Label: FECHA
# Texto: l ccoonn mm ee nn oo rer se s dd ee eeddaadd. . EEll jj uu ee zz ddeetteermrminianraar á llaa rreellaaccioiónn dd ii rr ee cc tata yy hhaabbitiutuaal l ccoonn mm ee nn oo rere s s dd ee ee dd aa dd dd ee l cc oo nn dd ee nan da od o pp aa rr aa i imm pp oo nn ee r r llaa iinnhhaabbiliidlidada d pp aa rr aa ee jj ee rr cc ee r r c caa rr gg oo ss , , oo ff ii cc ioio ss Oo pp rr oo fefe sis oi no en se s pp oo r r ddeelliittooss sseexxuuaalelse s ccoonntrtara mm ee nn oo rere s.s . PP aa rr aá gg rar fa o.f o. LL oo ss c caa rr gg oo ss , , oo ff ii cc ioio ss Oo p prr oo ff ee ss ioio nen se s e enn uu nn cc iaia dod so ,s , pp uu ee dd ee nn sseerr e ejj ee cc uu tata dod so s eenn eell mmaarrccoo dd ee uunnaa rreellaaccioiónn dd ee ccaarraáccteter r rreemmuunneerardaod o Oo nnoo r ree mm uu nn ee rar da od ;o ; eenn cc aa uu ss aa 22 | Label: EPIGRAFE
# === spaCy Entities ===
# Texto: ° | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: MM | Label: FECHA
# Texto: if | Label: FECHA
# Texto: 11991188 | Label: FECHA
# Texto: 00 | Label: FECHA
# Texto: 11 | Label: FECHA
# Texto: n | Label: FECHA
# Texto: l/ oo pp ee rr ss oo nn asa s nnaattuuraralelse s ccoonntrtaratatantnetse, s, ssaannccioión n c coo nn ss isis tet ne tn e te eenn mmuullttaa ee qq uu iviv aa lel ne tn e te aall vv aa lolo r r dd ee cciinnccuueenntat a ( (55 00 )) aa qq uu inin ieie ntn ot so s (( 55 | Label: EPIGRAFE
# Texto: mmiínnimimoos | Label: FECHA
# Texto: fo | Label: NUMERO_LEY
# Texto: iinncciissoo | Label: FECHA
# Texto: mim | Label: FECHA
# Texto: ivt | Label: FECHA
# Texto: ne | Label: FECHA
# Texto: iac | Label: FECHA
# Texto: 00 | Label: FECHA
# Texto: 99 | Label: FECHA
# Texto: 88 | Label: FECHA
# Texto: ddee | Label: NUMERO_LEY
# Texto: 220066 | Label: FECHA
# Texto: llaa | Label: FECHA
# Texto: 22 | Label: NUMERO_LEY
# Texto: 00 | Label: FECHA
# Texto: 11 | Label: FECHA
# Texto: fo | Label: FECHA
# Texto: mrm | Label: FECHA
# Texto: ene | Label: FECHA
# Texto: ten | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: tt | Label: FECHA
# Texto: ií | Label: FECHA
# Texto: 44 | Label: FECHA
# Texto: 220011 | Label: NUMERO_LEY
# Texto: fo | Label: FECHA
# Texto: io | Label: FECHA
# Texto: 11 | Label: FECHA
# Texto: 00 | Label: FECHA
# Texto: 11 | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: nió | Label: FECHA
# Texto: n | Label: FECHA
# Texto: FFeecchhaa | Label: FECHA
# Texto: ° | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: .. | Label: FECHA
# Texto: 00 | Label: FECHA
# Texto: 220044 | Label: NUMERO_LEY
# Texto: AARRTTICíCUULOL | Label: FECHA
# Texto: 11 | Label: FECHA
# Texto: 00 | Label: FECHA
# Texto: sis | Label: FECHA
# Texto: oi | Label: FECHA
# Texto: l | Label: FECHA
# Texto: 60 | Label: FECHA
# Texto: coo | Label: FECHA
# Texto: nn | Label: FECHA
# === spaCy Entities ===
# Texto: 2375 | Label: NUMERO_LEY
# === spaCy Entities ===
# Texto: 2'=>t"1h | Label: NUMERO_LEY
# Texto: 2 | Label: FECHA
# Texto: -3 | Label: FECHA
# Texto: -7 | Label: FECHA
# Texto: ES | Label: FECHA
# Texto: 12 | Label: FECHA
# Texto: ene | Label: FECHA
# Texto: 00 | Label: FECHA
# === spaCy Entities ===
# Texto: 2375 | Label: NUMERO_LEY
# Texto: HHoojjaa | Label: FECHA
# Texto: 22 | Label: FECHA
# Texto: ' | Label: NUMERO_LEY
# Texto: ~v--'2 | Label: FECHA
# Texto: ~ | Label: FECHA
# Texto: ' | Label: FECHA
# Metadatos guardados en: c:/Users/Jorge/OneDrive/Documents/proyect/document/json_output_2024\LEY-2375-2024.json
# === spaCy Entities ===
# Texto: 2376 | Label: FECHA
# Texto: 2376 | Label: NUMERO_LEY
# Texto: .~--12 | Label: FECHA
# Texto: JUL2024 | Label: FECHA
# Texto: ~~==~-- | Label: FECHA
# Texto: ° | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: tit | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: nn | Label: FECHA
# Texto: ip | Label: FECHA
# Texto: nen | Label: FECHA
# Texto: ce | Label: FECHA
# Texto: iec | Label: FECHA
# Texto: nie | Label: FECHA
# Texto: ten | Label: FECHA
# Texto: st | Label: FECHA
# Texto: AArrtitcíuclou | Label: FECHA
# Texto: lo | Label: FECHA
# Texto: 22 | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: coo | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: tt | Label: FECHA
# Texto: AArrtitcíuclou | Label: FECHA
# Texto: lo | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: .. | Label: FECHA
# Texto: ic | Label: FECHA
# Texto: llaa | Label: FECHA
# Texto: 00 | Label: FECHA
# Texto: 66 | Label: FECHA
# Texto: 22 | Label: NUMERO_LEY
# Texto: 00 | Label: FECHA
# Texto: 22 | Label: FECHA
# Texto: 2233 | Label: NUMERO_LEY
# Texto: llaa | Label: FECHA
# Texto: 99 | Label: FECHA
# Texto: 99 | Label: FECHA
# Texto: tit | Label: FECHA
# Texto: tt | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: ll | Label: FECHA
# Texto: n | Label: FECHA
# Texto: ssiisstteemmaa | Label: FECHA
# Texto: ií | Label: FECHA
# Texto: mm | Label: FECHA
# Texto: isis | Label: FECHA
# Texto: ne | Label: FECHA
# Texto: iac sia , s, i in ncc l! uu iri r pp ll aa nn ee ss , , pp rr oo gg rar mam asa s yy l/ oo pp rr oo yy ee cc tot so ,s , qq uu ee pp uu ee dd aa n n a app oo rr tata r r aall ff oo rr tt az le!e cic mim ienie ton to dd ee ll oo ss aa ss pp ee cc tot so s a amm bb ieie nn | Label: EPIGRAFE
# Texto: isÍs | Label: FECHA
# Texto: tit | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: ará | Label: FECHA
# Texto: fo | Label: FECHA
# Texto: rr | Label: NUMERO_LEY
# Texto: ií | Label: FECHA
# Texto: ssiisstetemma | Label: FECHA
# === spaCy Entities ===
# Texto: 2376 | Label: NUMERO_LEY
# Texto: izi | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: ttuurriissmmoo | Label: FECHA
# Texto: io | Label: NUMERO_LEY
# Texto: 44 | Label: NUMERO_LEY
# Texto: ° | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: nle | Label: FECHA
# Texto: aca | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: nió | Label: FECHA
# Texto: n | Label: FECHA
# Texto: fif | Label: FECHA
# Texto: ci | Label: FECHA
# Texto: ic | Label: FECHA
# Texto: ssiisstteemmaa | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: aca | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: nió | Label: FECHA
# Texto: n | Label: FECHA
# Texto: izi | Label: FECHA
# Texto: llaa | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: ieie | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: 55 | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: Mii | Label: FECHA
# Texto: ieie | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: ic | Label: FECHA
# Texto: ne | Label: FECHA
# Texto: iac sia , s, rreeaalilzizaararná n ll aa ss aaccioionnese s nn ee cc ee sas ra iari sa s pp aa rr aa aa pp oo yy aa r,r , c ca app aa cc iti ata r,r , bb rr inin dd aa r r a ass ee ss oo rir aí a yy aa cc oo mm pap na añ ma im eni te on to aa llaa pp oo bb lala cic oi nó n yy a auu tt oo rir did ada ed se s qq uu ee p prr oo mm uu ee vav na n yy ddeessaarrorollellne n pp rr oo gg rara mm asa s aammbbieienntatlaelse s ssuusstteenntatbalbelse s ccoonn ee nn fofo qq ueu e dd ee gg éé nn ee ror ,o , ttuurriísstitcicoso s yy ,, e ecc oo loló gg ici oc so s yy pp ee ss qq uu ee ror so s ddeenntrtoro dd ee lala zz oo nn aa dd ee iinnfflulueenncicai a dd ee llaa Ciénaga de la Zapatosa, la Ciénaga de Mallorquín y la Ciénaga de Zapayán. Ciénaga de la Zapatosa, la Ciénaga de Mallorquin y la Ciénaga de Zapayan. PP aa rr aá gg rar fa o fo 11 .. PP aa rr aa llaa eellaabbooraracicoinó n dd ee ll oo ss pp rr oo gg rara mm asa s aammbbieienntatlaesle s ss uu ss tete nn tat ba lb esle , s, qq uu ee ffoommeennteten n eell pp rr oo gg rere sos o dd ee l l pp ee ss cc aa dd oro r a arr tt ee ss aa nn ala , l, ssee aauuttoorrizizaa aall DD ee pp aa rtr at mam ene ton to AAddmmininisitsratrtiavoti vo NN aa cc ioio nan la l dd ee EEssttaaddisítsictiac a (( DD AA NN EE ),) , pp aa rr aa rr ee aa lil ziz aa r r uunnaa cc aa rr aa cc tet re izr aiz ca ioc ni ón ccoonn iinnddicicaaddoroerse s ss oo cc ioio ee coc no on mó im coi sc ,o s, dd ee ll aa ss ccoommuunnidiaddaedse s pp ee ss qq uu ee rar sa s aarrtteessaannalaelse s con enfoque de género. PP aa rr aá gg rar fa o fo 22.. SS ee FFoommeenntatarar á eell ddeessaarrorlololl o dd ee pp rr oo yy ee ctc ot so s tt uu rr isís tit ci | Label: EPIGRAFE
# Texto: ssiisstteemmaa | Label: FECHA
# Texto: il | Label: FECHA
# Texto: ipip | Label: FECHA
# Texto: idil | Label: FECHA
# Texto: aid | Label: FECHA
# Texto: ° | Label: NUMERO_LEY
# Texto: ° | Label: FECHA
# Texto: .. | Label: FECHA
# Texto: trt | Label: FECHA
# Texto: ir | Label: FECHA
# Texto: foo | Label: FECHA
# Texto: llaa | Label: FECHA
# Texto: olo | Label: FECHA
# Texto: ioi | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: uu | Label: FECHA
# Texto: ici | Label: FECHA
# Texto: ic | Label: FECHA
# Texto: ir | Label: FECHA
# Texto: quq | Label: FECHA
# Texto: 2 | Label: FECHA
# === spaCy Entities ===
# Texto: 2376 | Label: NUMERO_LEY
# Texto: ccoonnffoormrmidiadda | Label: FECHA
# Texto: s | Label: FECHA
# Texto: ioc | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: rr | Label: NUMERO_LEY
# Texto: ií | Label: FECHA
# Texto: 22 | Label: FECHA
# Texto: 88 | Label: FECHA
# Texto: 44 | Label: FECHA
# Texto: 55 | Label: FECHA
# Texto: ne | Label: FECHA
# Texto: iac | Label: FECHA
# Texto: 99 | Label: FECHA
# Texto: 00 | Label: FECHA
# Texto: 11 | Label: FECHA
# Texto: 00 | Label: FECHA
# Texto: ncn | Label: FECHA
# Texto: iac | Label: FECHA
# Texto: ait | Label: FECHA
# Texto: ieie | Label: FECHA
# Texto: nn tat | Label: EPIGRAFE
# Texto: ií | Label: FECHA
# Texto: eenn | Label: FECHA
# Texto: tt | Label: FECHA
# Texto: ií | Label: FECHA
# Texto: ibi | Label: FECHA
# Texto: 7 | Label: FECHA
# Texto: ° | Label: FECHA
# Texto: EEll | Label: FECHA
# Texto: ssiisstteemmaa | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: aca | Label: FECHA
# Texto: ssiisstteemmaa | Label: FECHA
# Texto: coo | Label: FECHA
# Texto: ° | Label: NUMERO_LEY
# Texto: ° | Label: NUMERO_LEY
# Texto: .. | Label: FECHA
# Texto: ii | Label: FECHA
# Texto: ioc | Label: FECHA
# === spaCy Entities ===
# Texto: 1)3 | Label: FECHA
# Texto: t | Label: NUMERO_LEY
# Texto: 2376 | Label: NUMERO_LEY
# === spaCy Entities ===
# Texto: ! | Label: FECHA
# Texto: -- | Label: FECHA
# Texto: 12 | Label: FECHA
# Texto: ior | Label: FECHA
# Texto: io | Label: FECHA
# Texto: ene | Label: FECHA
# Texto: 00 | Label: FECHA
# Texto: \. | Label: FECHA
# Texto: í | Label: FECHA
# Texto: ) | Label: NUMERO_LEY
# Texto: ~ | Label: FECHA
# Texto: vv | Label: FECHA
# Texto: le | Label: FECHA
# === spaCy Entities ===
# Texto: 2376 | Label: NUMERO_LEY
# Texto: HHoojjaa | Label: FECHA
# Texto: 22 | Label: FECHA
# Texto: 2376 | Label: FECHA
# Texto: 12 | Label: FECHA
# Metadatos guardados en: c:/Users/Jorge/OneDrive/Documents/proyect/document/json_output_2024\LEY-2376-2024.json

# %%
# pdf_path = r"C:\Users\Jorge\OneDrive\Documents\proyect\document\leyes\LEY-2351-2024.pdf"

# all_text = ""
# with pdfplumber.open(pdf_path) as pdf:
#     for i, page in enumerate(pdf.pages):
#         page_text = page.extract_text() or ""
#         print(f"--- Página {i} ---")
#         print(repr(page_text))
#         print("---------------")
#         all_text += page_text + "\n"
