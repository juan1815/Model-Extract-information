# %% [markdown]
# ## Librerias

# %%
import re
import spacy
import random
from spacy.training import Example
from spacy.util import minibatch, compounding
from typing import Optional
import logging
import os
import json
import unicodedata

# %%
# Configura el logging al principio del script (o en un archivo de configuración separado)
logging.basicConfig(level=logging.INFO,  # Nivel de detalle (INFO, DEBUG, WARNING, ERROR, CRITICAL)
                    format='%(asctime)s - %(levelname)s - %(message)s')

# %% [markdown]
# ## Funciones de limpieza OCR

# %%
def fix_ocr_issues_for_training(text: str) -> str:
    """
    Limpia el texto para entrenamiento, con manejo de Unicode y regex más precisas.
    """
    # Normalizar caracteres Unicode
    text = unicodedata.normalize("NFKC", text)

    # Unificar formatos de fechas: día, abreviatura de mes y año sin espacios intermedios
    text = re.sub(
        r"(?P<dia>\d{1,2})\s*(?P<mes>ENE|FEB|MAR|ABR|MAY|JUN|JUL|AGO|SEP|OCT|NOV|DIC)\s*(?P<año>\d{4})",
        r"\g<dia>\g<mes>\g<año>",
        text,
        flags=re.IGNORECASE
    )
    # Alternativa: unir dígitos separados por espacios (si fuera necesario)
    text = re.sub(
        r"(?P<dia>\d{1,2})\s+(?P<mes>ENE|FEB|MAR|ABR|MAY|JUN|JUL|AGO|SEP|OCT|NOV|DIC)\s+(?P<año>\d{4})",
        r"\g<dia>\g<mes>\g<año>",
        text,
        flags=re.IGNORECASE
    )

    # Quitar saltos de línea y guiones que interrumpen palabras
    text = re.sub(r"(\w+)\s+-\s+(\w+)", r"\1\2", text)  # Ej.: "mani-  festación" -> "manifestación"
    text = re.sub(r"(\w+)\n(\w+)", r"\1\2", text)         # Ej.: "mani\nfes" -> "manifes"
    text = re.sub(r"(\w+)-(\n)(\w+)", r"\1\3", text)       # Guion seguido de salto de línea

    # Eliminar espacios extras y normalizar puntuación
    text = re.sub(r"\s+", " ", text).strip()
    text = re.sub(r"[:;,.]+", ". ", text)

    return text

# %% [markdown]
# ## Context

# %%
raw_text_list = [
    """2353 17ABR2024 LEY No. "POR MEDIO DE LA CUAL...""",
    """2355 2024 LEY No. 17MAY "POR MEDIO DE LA CUAL...""",
    # ...
]

def add_new_examples(raw_text_list, train_data, output_file="train_data.json", interactive=True):
    """
    Agrega nuevos ejemplos, los anota (manualmente o no) y guarda TRAIN_DATA.

    Args:
        raw_text_list: Lista de textos crudos.
        train_data: Lista de entrenamiento actual (se modifica in-place).
        output_file: Nombre del archivo JSON para guardar.
        interactive:  Si es True, pide anotación manual. Si es False,
                      asume que las entidades ya están en raw_text_list.
    """
    for raw_text in raw_text_list:
        cleaned_text = fix_ocr_issues_for_training(raw_text)

        if interactive:
            print("=== Texto limpio para anotar ===")
            print(cleaned_text)
            print("Longitud:", len(cleaned_text))
            entities = []
            while True:
                try:
                    start = int(input("Inicio de entidad (o -1 para terminar): "))
                    if start == -1:
                        break
                    end = int(input("Fin de entidad: "))
                    label = input("Etiqueta: ")
                    entities.append((start, end, label))
                except ValueError:
                    print("Entrada inválida. Ingresa números enteros.")
        else:
            # Modo no interactivo: buscar coincidencias en los datos existentes
            found = False
            for i, (existing_text, annotations) in enumerate(train_data):
                if existing_text == cleaned_text:
                    entities = annotations.get("entities", [])
                    found = True
                    # Eliminar duplicados si existen
                    del train_data[i]
                    break
            if not found:
                print(f"WARNING: Texto '{cleaned_text}' no encontrado. Se añade sin entidades.")
                entities = []

        train_data.append((cleaned_text, {"entities": entities}))

    # Guardar los datos de entrenamiento en formato JSON
    try:
        with open(output_file, "w", encoding="utf-8") as f:
            json.dump(train_data, f, ensure_ascii=False, indent=4)
        print(f"TRAIN_DATA actualizado guardado en {output_file}")
    except Exception as e:
        logging.error(f"Error al guardar TRAIN_DATA: {e}")

    return train_data

# %% [markdown]
# ### Para cargar TRAIN_DATA desde el archivo:

# %%
def load_train_data(input_file="train_data.json"):
    """Carga los datos de entrenamiento desde un archivo JSON."""
    try:
        with open(input_file, "r", encoding="utf-8") as f:
            train_data = json.load(f)
            return train_data
    except FileNotFoundError:
        logging.warning(f"Archivo de datos de entrenamiento no encontrado: {input_file}. Se usará una lista vacía.")
        return []
    except json.JSONDecodeError:
        logging.error(f"Error al decodificar el archivo JSON: {input_file}. Verifica el formato.")
        return []
    except Exception as e:
        logging.error(f"Error inesperado al cargar TRAIN_DATA: {e}")
        return []

# %% [markdown]
# ## load the data

# %%
# 1. Carga los datos existentes (si los hay)
TRAIN_DATA = load_train_data()
if not TRAIN_DATA:
    TRAIN_DATA = [
        (
            '2182 3ENE2022 LEY No "POR MEDIO DEL CUAL SE MODIFICA EL ARTICULO 13 DE LA LEY ) 2002" EL CONGRESO DE COLOMBIA',
            {"entities": [
                (0, 4, "NUMERO_LEY"),   # "2182"
                (5, 13, "FECHA"),        # "3ENE2022"
                (14, 103, "EPIGRAFE")     # "LEY No  POR MEDIO DEL CUAL SE MODIFICA EL ARTICULO 13 DE LA LEY ) 2002"
            ]}
        ),
        (
            '2184 6ENE2022 LEY No. POR MEDIO DE LA CUAL SE DICTAN NORMAS ENCAMINADAS A FOMENTAR, PROMOVER LA SOSTENIBILIDAD, LA VALORACION Y LA TRANSMISION DE LOS SABERES DE LOS OFICIOS ARTISTICOS, DE LAS INDUSTRIAS CREATIVAS Y CULTURALES, ARTESANALES Y DEL PATRIMONIO CULTURAL EN COLOMBIA Y SE DICTAN OTRAS DISPOSICIONES EL CONGRESO DE COLOMBIA',
            {"entities": [
                (0, 4, "NUMERO_LEY"),   # "2184"
                (5, 13, "FECHA"),        # "6ENE2022"
                (14, 236, "EPIGRAFE")     # Epígrafe completo
            ]}
        ),
        (
            '2185 ENE2022 LEY No "POR MEDIO DE LA CUAL SE CREA EL FESTIVAL NACIONAL DE LA MARIMBA DE CHONTA, Y SE DICTAN OTRAS DISPOSICIONES" EL CONGRESO DE COLOMBIA',
            {"entities": [
                (0, 4, "NUMERO_LEY"),   # "2185"
                (5, 12, "FECHA"),        # "ENE2022" (Aquí no se incluye el día, por lo que podrías ajustar la normalización si fuera necesario)
                (13, 120, "EPIGRAFE")     # Epígrafe completo
            ]}
        ),
    ]


# *nuevos* ejemplos *manualmente*, usa add_new_examples
#    en modo interactivo (sin el `interactive=False`):
nuevos_textos = [
   """8 FEB 2022
    - ...
    LEY ORGANICA No2199
    "POR MEDIO DE LA CUAL..." ...
    """,
]
TRAIN_DATA = add_new_examples(nuevos_textos, TRAIN_DATA)
# Out:
# 2025-03-21 11:53:04,260 - WARNING - Archivo de datos de entrenamiento no encontrado: train_data.json. Se usará una lista vacía.
# === Texto limpio para anotar ===
# 8FEB2022 - .  LEY ORGANICA No2199 "POR MEDIO DE LA CUAL. " .
# Longitud: 61
# Entrada inválida. Ingresa números enteros.
# Entrada inválida. Ingresa números enteros.
# Entrada inválida. Ingresa números enteros.
# Entrada inválida. Ingresa números enteros.
# TRAIN_DATA actualizado guardado en train_data.json

# %% [markdown]
# ## date Change

# %%
def load_spacy_model(model_path="modelo_leyes_epigrafe"):
    return spacy.load(model_path)

def normalize_spacy_date(spacy_fecha: str) -> Optional[str]:
    """
    Normaliza fechas y registra errores.
    """
    month_map = {
        "ENE": "01", "FEB": "02", "MAR": "03", "ABR": "04",
        "MAY": "05", "JUN": "06", "JUL": "07", "AGO": "08",
        "SEP": "09", "OCT": "10", "NOV": "11", "DIC": "12"
    }

    m = re.match(r"(\d{1,2})([A-Z]{3,4})(\d{4})", spacy_fecha.upper())
    if not m:
        logging.warning(f"No se pudo normalizar la fecha: {spacy_fecha}") # Registro
        return None  # O devolver la fecha original, según prefieras
    day = m.group(1).zfill(2)
    mes_str = m.group(2)
    year = m.group(3)
    mes_num = month_map.get(mes_str)
    if not mes_num:
        logging.warning(f"Mes desconocido en fecha: {spacy_fecha}") # Registro
        return None  # O devolver la fecha original
    return f"{day}/{mes_num}/{year}"

# %% [markdown]
# ## train model

# %%
def train_spacy_model(train_data, output_dir="modelo_leyes_epigrafe", n_iter=30, learning_rate=0.001, dropout_rate=0.2):

    # Crear un modelo en blanco para español e incorporar el componente de NER
    nlp = spacy.blank("es")
    ner = nlp.add_pipe("ner", last=True)

    # Añadir etiquetas al componente NER basándose en las anotaciones de train_data
    for _, annotations in train_data:
        for ent in annotations.get("entities", []):
            ner.add_label(ent[2])  # ent[2] corresponde a la etiqueta

    # Mezclar y dividir los datos en entrenamiento (80%) y validación (20%)
    random.shuffle(train_data)
    split = int(len(train_data) * 0.8)
    train_examples_raw = train_data[:split]
    dev_examples_raw = train_data[split:]


    # Preparar ejemplos de entrenamiento y validación
    def prepare_examples(data):
        examples = []
        for text, annotations in data:
            doc = nlp.make_doc(text)
            # Se espera que annotations tenga la estructura {"entities": [(inicio, fin, etiqueta), ...]}
            example = Example.from_dict(doc, annotations)
            examples.append(example)
        return examples

    train_examples = prepare_examples(train_examples_raw)
    dev_examples = prepare_examples(dev_examples_raw)

    # Inicializar el entrenamiento; si se requiere ajustar la tasa de aprendizaje, 
    # se podría configurar el optimizador en base a "learning_rate" (actualmente no se utiliza)
    optimizer = nlp.begin_training()

    # Ciclo de entrenamiento
    for i in range(n_iter):
        random.shuffle(train_examples)
        losses = {}
        # Usar batches de tamaño dinámico
        batches = minibatch(train_examples, size=compounding(4.0, 32.0, 1.001))
        for batch in batches:
            # Actualiza el modelo usando el batch actual, aplicando dropout para evitar overfitting
            nlp.update(batch, drop=dropout_rate, losses=losses, sgd=optimizer)
        print(f"Época {i + 1}, pérdidas: {losses}")

        # Evaluar el modelo en el conjunto de validación y mostrar resultados
        scores = nlp.evaluate(dev_examples)
        print(f"  Resultados en validación: {scores}")

    # Guardar el modelo entrenado en disco
    nlp.to_disk(output_dir)
    print(f"Modelo guardado en: {output_dir}")

    return nlp

# Entrenar
#nlp_trained = train_spacy_model(TRAIN_DATA, "modelo_leyes_epigrafe")

# %% [markdown]
# ## ejemplo de uso

# %%
# nlp_trained = load_spacy_model("modelo_leyes_epigrafe")

# test_text = "2353 17ABR2024 LEY No. ... El Congreso de Colombia,"
# test_text = fix_ocr_issues_for_training(test_text)  # Limpieza
# doc = nlp_trained(test_text)
# for ent in doc.ents:
#     if ent.label_ == "FECHA":
#         fecha_normalizada = normalize_spacy_date(ent.text)
#         print("Fecha final:", fecha_normalizada)
#     else:
#         print(ent.text, ent.label_)

# %% [markdown]
# ## Section final

# %%
def spacy_extract_metadata(text: str, nlp) -> dict:
    # Limpiar el texto antes de procesarlo (se utiliza la función de corrección de OCR)
    text_clean = fix_ocr_issues_for_training(text)
    doc = nlp(text_clean)
    result = {
        "numero_ley": None,
        "fecha": None,
        "epigrafe": None
    }
    # Recorrer las entidades detectadas y asignarlas al diccionario de resultados
    for ent in doc.ents:
        if ent.label_ == "NUMERO_LEY":
            result["numero_ley"] = ent.text
        elif ent.label_ == "FECHA":
            # Normalizar la fecha a formato DD/MM/AAAA usando la función correspondiente
            fecha_norm = normalize_spacy_date(ent.text)
            result["fecha"] = fecha_norm if fecha_norm else ent.text
        elif ent.label_ == "EPIGRAFE":
            result["epigrafe"] = ent.text

    return result

# %% [markdown]
# ## function to extract data

# %%
def extract_metadata_from_txt(txt_path: str, nlp=None) -> dict:
    """
    Lee un archivo .txt, extrae metadatos y maneja errores.
    """
    try:
        with open(txt_path, "r", encoding="utf-8") as f:
            content = f.read()
    except FileNotFoundError:
        logging.error(f"Archivo no encontrado: {txt_path}")
        return None  # O un diccionario vacío, según prefieras
    except UnicodeDecodeError:
        logging.error(f"Error de codificación al leer: {txt_path}")
        return None
    except Exception as e:
        logging.error(f"Error inesperado al leer {txt_path}: {e}")
        return None

    if nlp:
        try:
            metadata = spacy_extract_metadata(content, nlp)
        except Exception as e:
            logging.error(f"Error al extraer metadatos con spaCy de {txt_path}: {e}")
            metadata = {}  # Diccionario vacío si falla spaCy
    else:
        metadata = {
            "numero_ley": None,
            "fecha": None,
            "tipo_ley": None,
            "epigrafe": None
        }

    return metadata

# %%
# def extract_metadata_from_txt(txt_path: str, nlp=None) -> dict:
#     """
#     Lee un archivo .txt y extrae los metadatos (numero_ley, fecha, etc.)
#     usando tu pipeline híbrida o la que definas.
#     """
#     import os

#     # 1) Abrir y leer el archivo .txt
#     with open(txt_path, "r", encoding="utf-8") as f:
#         content = f.read()

#     # 2) Llamar a tu función de extracción (regex + spaCy)
#     #    Por ejemplo, si definiste extract_metadata_layout_hybrid:
#     if nlp:
#         metadata = spacy_extract_metadata(content, nlp)
#     else:
#         # Si no pasas un nlp, podrías usar solo regex
#         # metadata = extract_metadata_layout_regex(content)
#         metadata = {
#             "numero_ley": None,
#             "fecha": None,
#             "tipo_ley": None,
#             "epigrafe": None
#         }

#     return metadata

# %% [markdown]
# ## USe

# %% [markdown]
# ### Process the carpet

# %%
def procesar_txt_en_carpeta(carpeta_txt: str, carpeta_salida: str, nlp=None):
    """
    Procesa archivos .txt, guarda metadatos en JSON y maneja errores.
    """
    os.makedirs(carpeta_salida, exist_ok=True)

    for archivo in os.listdir(carpeta_txt):
        if archivo.lower().endswith(".txt"):
            ruta_txt = os.path.join(carpeta_txt, archivo)
            metadatos = extract_metadata_from_txt(ruta_txt, nlp)

            if metadatos:  # Solo guarda si se extrajeron metadatos
                nombre_json = os.path.splitext(archivo)[0] + ".json"
                ruta_json = os.path.join(carpeta_salida, nombre_json)
                try:
                    with open(ruta_json, "w", encoding="utf-8") as f:
                        json.dump(metadatos, f, ensure_ascii=False, indent=4)
                    logging.info(f"Metadatos guardados en: {ruta_json}")
                except Exception as e:
                    logging.error(f"Error al guardar JSON para {archivo}: {e}")

# %%
if __name__ == "__main__":
    # 1) Rutas
    carpeta_txt = r"C:\Users\Jorge\OneDrive\Documents\proyect\document\leyes"
    carpeta_salida = r"C:\Users\Jorge\OneDrive\Documents\proyect\document\json_output_2022"

    # 2) Cargar el modelo spaCy (si lo usas)
    import spacy
    nlp_trained = spacy.load("modelo_leyes_epigrafe")  # o la ruta a tu modelo

    # 3) Procesar la carpeta
    procesar_txt_en_carpeta(carpeta_txt, carpeta_salida, nlp_trained)

# Entrenar
nlp_trained = train_spacy_model(TRAIN_DATA, "modelo_leyes_epigrafe")

#Ejemplo de Uso
nlp_trained = load_spacy_model("modelo_leyes_epigrafe")

test_text = "2353 17ABR2024 LEY No. ... El Congreso de Colombia,"
test_text = fix_ocr_issues_for_training(test_text)  # Limpieza
doc = nlp_trained(test_text)
for ent in doc.ents:
    if ent.label_ == "FECHA":
        fecha_normalizada = normalize_spacy_date(ent.text)
        print("Fecha final:", fecha_normalizada)
    else:
        print(ent.text, ent.label_)
# Out:
# 2025-03-21 11:55:16,413 - WARNING - No se pudo normalizar la fecha: modificar
# 2025-03-21 11:55:16,413 - WARNING - No se pudo normalizar la fecha: y
# 2025-03-21 11:55:16,414 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:16,415 - WARNING - No se pudo normalizar la fecha: requisitos
# 2025-03-21 11:55:16,416 - WARNING - No se pudo normalizar la fecha: establecidos
# 2025-03-21 11:55:16,417 - WARNING - No se pudo normalizar la fecha: 1992
# 2025-03-21 11:55:16,419 - WARNING - No se pudo normalizar la fecha: reforma
# 2025-03-21 11:55:16,420 - WARNING - No se pudo normalizar la fecha: estatutaria
# 2025-03-21 11:55:16,421 - WARNING - No se pudo normalizar la fecha: instituciones
# 2025-03-21 11:55:16,422 - WARNING - No se pudo normalizar la fecha: acogerse
# 2025-03-21 11:55:16,423 - WARNING - No se pudo normalizar la fecha: al
# 2025-03-21 11:55:16,424 - WARNING - No se pudo normalizar la fecha: manera
# 2025-03-21 11:55:16,426 - WARNING - No se pudo normalizar la fecha: 1
# 2025-03-21 11:55:16,430 - INFO - Metadatos guardados en: C:\Users\Jorge\OneDrive\Documents\proyect\document\json_output_2022\LEY-2182-2022plaintext.json
# 2025-03-21 11:55:16,745 - WARNING - No se pudo normalizar la fecha: 2183
# 2025-03-21 11:55:16,746 - WARNING - No se pudo normalizar la fecha: 2022
# 2025-03-21 11:55:16,747 - WARNING - No se pudo normalizar la fecha: establecer
# 2025-03-21 11:55:16,749 - WARNING - No se pudo normalizar la fecha: como
# 2025-03-21 11:55:16,750 - WARNING - No se pudo normalizar la fecha: para
# 2025-03-21 11:55:16,752 - WARNING - No se pudo normalizar la fecha: una
# 2025-03-21 11:55:16,753 - WARNING - No se pudo normalizar la fecha: instancia
# 2025-03-21 11:55:16,755 - WARNING - No se pudo normalizar la fecha: asesoria
# 2025-03-21 11:55:16,756 - WARNING - No se pudo normalizar la fecha: busquen
# 2025-03-21 11:55:16,757 - WARNING - No se pudo normalizar la fecha: incrementar
# 2025-03-21 11:55:16,758 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:16,758 - WARNING - No se pudo normalizar la fecha: internacionales
# 2025-03-21 11:55:16,760 - WARNING - No se pudo normalizar la fecha: efectuar
# 2025-03-21 11:55:16,762 - WARNING - No se pudo normalizar la fecha: recomendaciones
# 2025-03-21 11:55:16,763 - WARNING - No se pudo normalizar la fecha: para
# 2025-03-21 11:55:16,765 - WARNING - No se pudo normalizar la fecha: como
# 2025-03-21 11:55:16,767 - WARNING - No se pudo normalizar la fecha: efectuar
# 2025-03-21 11:55:16,768 - WARNING - No se pudo normalizar la fecha: recomendaciones
# 2025-03-21 11:55:16,769 - WARNING - No se pudo normalizar la fecha: realizara
# 2025-03-21 11:55:16,770 - WARNING - No se pudo normalizar la fecha: para
# 2025-03-21 11:55:16,772 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:16,772 - WARNING - No se pudo normalizar la fecha: resolucion
# 2025-03-21 11:55:16,773 - WARNING - No se pudo normalizar la fecha: suscrita
# 2025-03-21 11:55:16,774 - WARNING - No se pudo normalizar la fecha: quien
# 2025-03-21 11:55:16,775 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:16,777 - WARNING - No se pudo normalizar la fecha: de
# 2025-03-21 11:55:16,778 - WARNING - No se pudo normalizar la fecha: agropecuarios
# 2025-03-21 11:55:16,779 - WARNING - No se pudo normalizar la fecha: acciones
# 2025-03-21 11:55:16,780 - WARNING - No se pudo normalizar la fecha: realizadas
# 2025-03-21 11:55:16,781 - WARNING - No se pudo normalizar la fecha: funciones
# 2025-03-21 11:55:16,783 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:16,784 - WARNING - No se pudo normalizar la fecha: con
# 2025-03-21 11:55:16,785 - WARNING - No se pudo normalizar la fecha: una
# 2025-03-21 11:55:16,786 - WARNING - No se pudo normalizar la fecha: instancia
# 2025-03-21 11:55:16,787 - WARNING - No se pudo normalizar la fecha: informacion
# 2025-03-21 11:55:16,788 - WARNING - No se pudo normalizar la fecha: relacionadas
# 2025-03-21 11:55:16,789 - WARNING - No se pudo normalizar la fecha: yl
# 2025-03-21 11:55:16,790 - WARNING - No se pudo normalizar la fecha: conl
# 2025-03-21 11:55:16,791 - WARNING - No se pudo normalizar la fecha: resuelva
# 2025-03-21 11:55:16,792 - WARNING - No se pudo normalizar la fecha: informacion
# 2025-03-21 11:55:16,794 - WARNING - No se pudo normalizar la fecha: oportunidad
# 2025-03-21 11:55:16,795 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:16,796 - WARNING - No se pudo normalizar la fecha: rezago
# 2025-03-21 11:55:16,798 - WARNING - No se pudo normalizar la fecha: la
# 2025-03-21 11:55:16,800 - WARNING - No se pudo normalizar la fecha: lal
# 2025-03-21 11:55:16,801 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:16,802 - WARNING - No se pudo normalizar la fecha: promover
# 2025-03-21 11:55:16,803 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:16,804 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:16,805 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:16,806 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:16,806 - WARNING - No se pudo normalizar la fecha: recursos
# 2025-03-21 11:55:16,808 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:16,814 - WARNING - No se pudo normalizar la fecha: desarrollar
# 2025-03-21 11:55:16,816 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:16,818 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:16,818 - WARNING - No se pudo normalizar la fecha: regionales
# 2025-03-21 11:55:16,820 - WARNING - No se pudo normalizar la fecha: donde
# 2025-03-21 11:55:16,822 - WARNING - No se pudo normalizar la fecha: reglamentara
# 2025-03-21 11:55:16,823 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:16,825 - WARNING - No se pudo normalizar la fecha: juridicas
# 2025-03-21 11:55:16,826 - WARNING - No se pudo normalizar la fecha: ejerzan
# 2025-03-21 11:55:16,829 - WARNING - No se pudo normalizar la fecha: 14
# 2025-03-21 11:55:16,830 - WARNING - No se pudo normalizar la fecha: mecanismos
# 2025-03-21 11:55:16,831 - WARNING - No se pudo normalizar la fecha: necesarios
# 2025-03-21 11:55:16,835 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:16,838 - WARNING - No se pudo normalizar la fecha: mejores
# 2025-03-21 11:55:16,839 - WARNING - No se pudo normalizar la fecha: del
# 2025-03-21 11:55:16,841 - WARNING - No se pudo normalizar la fecha: acciones
# 2025-03-21 11:55:16,843 - WARNING - No se pudo normalizar la fecha: mujeres
# 2025-03-21 11:55:16,844 - WARNING - No se pudo normalizar la fecha: rurales
# 2025-03-21 11:55:16,845 - WARNING - No se pudo normalizar la fecha: del
# 2025-03-21 11:55:16,848 - WARNING - No se pudo normalizar la fecha: patrimonio
# 2025-03-21 11:55:16,851 - WARNING - No se pudo normalizar la fecha: fiducia
# 2025-03-21 11:55:16,853 - WARNING - No se pudo normalizar la fecha: donde
# 2025-03-21 11:55:16,854 - WARNING - No se pudo normalizar la fecha: sul
# 2025-03-21 11:55:16,855 - WARNING - No se pudo normalizar la fecha: fiducia
# 2025-03-21 11:55:16,856 - WARNING - No se pudo normalizar la fecha: que
# 2025-03-21 11:55:16,857 - WARNING - No se pudo normalizar la fecha: designe
# 2025-03-21 11:55:16,858 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:16,860 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:16,861 - WARNING - No se pudo normalizar la fecha: adopte
# 2025-03-21 11:55:16,862 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:16,863 - WARNING - No se pudo normalizar la fecha: politicas
# 2025-03-21 11:55:16,864 - WARNING - No se pudo normalizar la fecha: con
# 2025-03-21 11:55:16,866 - WARNING - No se pudo normalizar la fecha: inversion
# 2025-03-21 11:55:16,867 - WARNING - No se pudo normalizar la fecha: 1
# 2025-03-21 11:55:16,869 - WARNING - No se pudo normalizar la fecha: les
# 2025-03-21 11:55:16,870 - WARNING - No se pudo normalizar la fecha: aporten
# 2025-03-21 11:55:16,872 - WARNING - No se pudo normalizar la fecha: entidades
# 2025-03-21 11:55:16,874 - WARNING - No se pudo normalizar la fecha: nivel
# 2025-03-21 11:55:16,875 - WARNING - No se pudo normalizar la fecha: ano
# 2025-03-21 11:55:16,876 - WARNING - No se pudo normalizar la fecha: recursos
# 2025-03-21 11:55:16,877 - WARNING - No se pudo normalizar la fecha: garantias
# 2025-03-21 11:55:16,877 - WARNING - No se pudo normalizar la fecha: importacion
# 2025-03-21 11:55:16,879 - WARNING - No se pudo normalizar la fecha: gestiones
# 2025-03-21 11:55:16,880 - WARNING - No se pudo normalizar la fecha: trata
# 2025-03-21 11:55:16,881 - WARNING - No se pudo normalizar la fecha: Articulo
# 2025-03-21 11:55:16,883 - WARNING - No se pudo normalizar la fecha: facultades
# 2025-03-21 11:55:16,885 - WARNING - No se pudo normalizar la fecha: régimen
# 2025-03-21 11:55:16,886 - WARNING - No se pudo normalizar la fecha: inexactitud
# 2025-03-21 11:55:16,886 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:16,887 - WARNING - No se pudo normalizar la fecha: reportada
# 2025-03-21 11:55:16,889 - WARNING - No se pudo normalizar la fecha: sanciones
# 2025-03-21 11:55:16,890 - WARNING - No se pudo normalizar la fecha: sobre
# 2025-03-21 11:55:16,891 - WARNING - No se pudo normalizar la fecha: investigaciones
# 2025-03-21 11:55:16,892 - WARNING - No se pudo normalizar la fecha: una
# 2025-03-21 11:55:16,893 - WARNING - No se pudo normalizar la fecha: solucion
# 2025-03-21 11:55:16,894 - WARNING - No se pudo normalizar la fecha: sanciones
# 2025-03-21 11:55:16,895 - WARNING - No se pudo normalizar la fecha: 1
# 2025-03-21 11:55:16,896 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:16,897 - WARNING - No se pudo normalizar la fecha: administrativo
# 2025-03-21 11:55:16,898 - WARNING - No se pudo normalizar la fecha: ano
# 2025-03-21 11:55:16,900 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:16,901 - WARNING - No se pudo normalizar la fecha: inversiones
# 2025-03-21 11:55:16,902 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:16,904 - WARNING - No se pudo normalizar la fecha: ultima
# 2025-03-21 11:55:16,905 - WARNING - No se pudo normalizar la fecha: incremente
# 2025-03-21 11:55:16,906 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:16,907 - WARNING - No se pudo normalizar la fecha: 2183
# 2025-03-21 11:55:16,909 - WARNING - No se pudo normalizar la fecha: lineamientos
# 2025-03-21 11:55:16,910 - WARNING - No se pudo normalizar la fecha: una
# 2025-03-21 11:55:16,911 - WARNING - No se pudo normalizar la fecha: demanda
# 2025-03-21 11:55:16,912 - WARNING - No se pudo normalizar la fecha: les
# 2025-03-21 11:55:16,913 - WARNING - No se pudo normalizar la fecha: permita
# 2025-03-21 11:55:16,914 - WARNING - No se pudo normalizar la fecha: igual
# 2025-03-21 11:55:16,915 - WARNING - No se pudo normalizar la fecha: que
# 2025-03-21 11:55:16,916 - WARNING - No se pudo normalizar la fecha: permita
# 2025-03-21 11:55:16,918 - WARNING - No se pudo normalizar la fecha: afecte
# 2025-03-21 11:55:16,919 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:16,921 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:16,922 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:16,925 - WARNING - No se pudo normalizar la fecha: periodo
# 2025-03-21 11:55:16,926 - WARNING - No se pudo normalizar la fecha: legales
# 2025-03-21 11:55:16,927 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:16,929 - WARNING - No se pudo normalizar la fecha: promover
# 2025-03-21 11:55:16,930 - WARNING - No se pudo normalizar la fecha: 2183
# 2025-03-21 11:55:16,931 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:16,946 - INFO - Metadatos guardados en: C:\Users\Jorge\OneDrive\Documents\proyect\document\json_output_2022\LEY-2183-2022plaintext.json
# 2025-03-21 11:55:17,512 - WARNING - No se pudo normalizar la fecha: patrimonio
# 2025-03-21 11:55:17,513 - WARNING - No se pudo normalizar la fecha: organizaciones
# 2025-03-21 11:55:17,514 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:17,517 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,519 - WARNING - No se pudo normalizar la fecha: aprendizaje
# 2025-03-21 11:55:17,520 - WARNING - No se pudo normalizar la fecha: materiales
# 2025-03-21 11:55:17,521 - WARNING - No se pudo normalizar la fecha: una
# 2025-03-21 11:55:17,522 - WARNING - No se pudo normalizar la fecha: del
# 2025-03-21 11:55:17,523 - WARNING - No se pudo normalizar la fecha: haran
# 2025-03-21 11:55:17,524 - WARNING - No se pudo normalizar la fecha: del
# 2025-03-21 11:55:17,525 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,526 - WARNING - No se pudo normalizar la fecha: proveera
# 2025-03-21 11:55:17,526 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,527 - WARNING - No se pudo normalizar la fecha: realice
# 2025-03-21 11:55:17,528 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,529 - WARNING - No se pudo normalizar la fecha: 1
# 2025-03-21 11:55:17,530 - WARNING - No se pudo normalizar la fecha: intervienen
# 2025-03-21 11:55:17,532 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,533 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,535 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,536 - WARNING - No se pudo normalizar la fecha: acciones
# 2025-03-21 11:55:17,537 - WARNING - No se pudo normalizar la fecha: igualdad
# 2025-03-21 11:55:17,539 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,541 - WARNING - No se pudo normalizar la fecha: formas
# 2025-03-21 11:55:17,542 - WARNING - No se pudo normalizar la fecha: integracion
# 2025-03-21 11:55:17,543 - WARNING - No se pudo normalizar la fecha: entre
# 2025-03-21 11:55:17,544 - WARNING - No se pudo normalizar la fecha: intervienen
# 2025-03-21 11:55:17,545 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,546 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,547 - WARNING - No se pudo normalizar la fecha: permitan
# 2025-03-21 11:55:17,552 - WARNING - No se pudo normalizar la fecha: intervienen
# 2025-03-21 11:55:17,554 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,556 - WARNING - No se pudo normalizar la fecha: brindados
# 2025-03-21 11:55:17,556 - WARNING - No se pudo normalizar la fecha: servicios
# 2025-03-21 11:55:17,558 - WARNING - No se pudo normalizar la fecha: con
# 2025-03-21 11:55:17,559 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,561 - WARNING - No se pudo normalizar la fecha: alcanzar
# 2025-03-21 11:55:17,561 - WARNING - No se pudo normalizar la fecha: patrimonio
# 2025-03-21 11:55:17,562 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,563 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,565 - WARNING - No se pudo normalizar la fecha: sesiones
# 2025-03-21 11:55:17,568 - WARNING - No se pudo normalizar la fecha: con
# 2025-03-21 11:55:17,570 - WARNING - No se pudo normalizar la fecha: una
# 2025-03-21 11:55:17,571 - WARNING - No se pudo normalizar la fecha: sel
# 2025-03-21 11:55:17,572 - WARNING - No se pudo normalizar la fecha: patrimonio
# 2025-03-21 11:55:17,574 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,575 - WARNING - No se pudo normalizar la fecha: estara
# 2025-03-21 11:55:17,576 - WARNING - No se pudo normalizar la fecha: instituciones
# 2025-03-21 11:55:17,577 - WARNING - No se pudo normalizar la fecha: instituciones
# 2025-03-21 11:55:17,579 - WARNING - No se pudo normalizar la fecha: instituciones
# 2025-03-21 11:55:17,581 - WARNING - No se pudo normalizar la fecha: instituciones
# 2025-03-21 11:55:17,586 - WARNING - No se pudo normalizar la fecha: para
# 2025-03-21 11:55:17,588 - WARNING - No se pudo normalizar la fecha: 1
# 2025-03-21 11:55:17,591 - WARNING - No se pudo normalizar la fecha: 1
# 2025-03-21 11:55:17,592 - WARNING - No se pudo normalizar la fecha: 1
# 2025-03-21 11:55:17,594 - WARNING - No se pudo normalizar la fecha: 1
# 2025-03-21 11:55:17,596 - WARNING - No se pudo normalizar la fecha: cuya
# 2025-03-21 11:55:17,599 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,603 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:17,605 - WARNING - No se pudo normalizar la fecha: no
# 2025-03-21 11:55:17,606 - WARNING - No se pudo normalizar la fecha: implicaran
# 2025-03-21 11:55:17,607 - WARNING - No se pudo normalizar la fecha: patrimonio
# 2025-03-21 11:55:17,609 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,611 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,613 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,614 - WARNING - No se pudo normalizar la fecha: aporten
# 2025-03-21 11:55:17,617 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,619 - WARNING - No se pudo normalizar la fecha: quienes
# 2025-03-21 11:55:17,621 - WARNING - No se pudo normalizar la fecha: programas
# 2025-03-21 11:55:17,622 - WARNING - No se pudo normalizar la fecha: educativos
# 2025-03-21 11:55:17,624 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,625 - WARNING - No se pudo normalizar la fecha: inversion
# 2025-03-21 11:55:17,629 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,631 - WARNING - No se pudo normalizar la fecha: nacional
# 2025-03-21 11:55:17,634 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,636 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,637 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,638 - WARNING - No se pudo normalizar la fecha: 1997
# 2025-03-21 11:55:17,640 - WARNING - No se pudo normalizar la fecha: con
# 2025-03-21 11:55:17,642 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,644 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,645 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,646 - WARNING - No se pudo normalizar la fecha: patrimonio
# 2025-03-21 11:55:17,649 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,651 - WARNING - No se pudo normalizar la fecha: con
# 2025-03-21 11:55:17,654 - WARNING - No se pudo normalizar la fecha: 2184
# 2025-03-21 11:55:17,655 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,658 - WARNING - No se pudo normalizar la fecha: estara
# 2025-03-21 11:55:17,659 - WARNING - No se pudo normalizar la fecha: artesanos
# 2025-03-21 11:55:17,661 - WARNING - No se pudo normalizar la fecha: Artesanal
# 2025-03-21 11:55:17,662 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:17,663 - WARNING - No se pudo normalizar la fecha: una
# 2025-03-21 11:55:17,665 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:17,666 - WARNING - No se pudo normalizar la fecha: anos
# 2025-03-21 11:55:17,669 - WARNING - No se pudo normalizar la fecha: con
# 2025-03-21 11:55:17,671 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,672 - WARNING - No se pudo normalizar la fecha: indicados
# 2025-03-21 11:55:17,674 - WARNING - No se pudo normalizar la fecha: al
# 2025-03-21 11:55:17,675 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,677 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,679 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,680 - WARNING - No se pudo normalizar la fecha: sesiones
# 2025-03-21 11:55:17,683 - WARNING - No se pudo normalizar la fecha: Articulo
# 2025-03-21 11:55:17,685 - WARNING - No se pudo normalizar la fecha: 10
# 2025-03-21 11:55:17,688 - WARNING - No se pudo normalizar la fecha: sector
# 2025-03-21 11:55:17,689 - WARNING - No se pudo normalizar la fecha: acciones
# 2025-03-21 11:55:17,690 - WARNING - No se pudo normalizar la fecha: para
# 2025-03-21 11:55:17,691 - WARNING - No se pudo normalizar la fecha: sector
# 2025-03-21 11:55:17,693 - WARNING - No se pudo normalizar la fecha: acciones
# 2025-03-21 11:55:17,695 - WARNING - No se pudo normalizar la fecha: al
# 2025-03-21 11:55:17,696 - WARNING - No se pudo normalizar la fecha: artesanal
# 2025-03-21 11:55:17,697 - WARNING - No se pudo normalizar la fecha: manifestaciones
# 2025-03-21 11:55:17,701 - WARNING - No se pudo normalizar la fecha: artesanales
# 2025-03-21 11:55:17,703 - WARNING - No se pudo normalizar la fecha: inversion
# 2025-03-21 11:55:17,705 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,706 - WARNING - No se pudo normalizar la fecha: para
# 2025-03-21 11:55:17,708 - WARNING - No se pudo normalizar la fecha: sector
# 2025-03-21 11:55:17,710 - WARNING - No se pudo normalizar la fecha: entidades
# 2025-03-21 11:55:17,711 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,713 - WARNING - No se pudo normalizar la fecha: sector
# 2025-03-21 11:55:17,714 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,716 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,719 - WARNING - No se pudo normalizar la fecha: sera
# 2025-03-21 11:55:17,721 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,722 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:17,724 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,725 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,726 - WARNING - No se pudo normalizar la fecha: instituciones
# 2025-03-21 11:55:17,727 - WARNING - No se pudo normalizar la fecha: articular
# 2025-03-21 11:55:17,729 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,731 - WARNING - No se pudo normalizar la fecha: requisitos
# 2025-03-21 11:55:17,732 - WARNING - No se pudo normalizar la fecha: establecidos
# 2025-03-21 11:55:17,734 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,736 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,736 - WARNING - No se pudo normalizar la fecha: no
# 2025-03-21 11:55:17,738 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,739 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,740 - WARNING - No se pudo normalizar la fecha: inscripcion
# 2025-03-21 11:55:17,742 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,743 - WARNING - No se pudo normalizar la fecha: recomendaciones
# 2025-03-21 11:55:17,745 - WARNING - No se pudo normalizar la fecha: ante
# 2025-03-21 11:55:17,746 - WARNING - No se pudo normalizar la fecha: patrimonio
# 2025-03-21 11:55:17,747 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,749 - WARNING - No se pudo normalizar la fecha: mecanismos
# 2025-03-21 11:55:17,753 - WARNING - No se pudo normalizar la fecha: articularse
# 2025-03-21 11:55:17,754 - WARNING - No se pudo normalizar la fecha: mecanismos
# 2025-03-21 11:55:17,755 - WARNING - No se pudo normalizar la fecha: para
# 2025-03-21 11:55:17,756 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,758 - WARNING - No se pudo normalizar la fecha: mecanismos
# 2025-03-21 11:55:17,759 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,761 - WARNING - No se pudo normalizar la fecha: mecanismos
# 2025-03-21 11:55:17,762 - WARNING - No se pudo normalizar la fecha: recomendaciones
# 2025-03-21 11:55:17,763 - WARNING - No se pudo normalizar la fecha: artesanal
# 2025-03-21 11:55:17,764 - WARNING - No se pudo normalizar la fecha: 13
# 2025-03-21 11:55:17,766 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,768 - WARNING - No se pudo normalizar la fecha: 14
# 2025-03-21 11:55:17,770 - WARNING - No se pudo normalizar la fecha: relacionada
# 2025-03-21 11:55:17,771 - WARNING - No se pudo normalizar la fecha: nivel
# 2025-03-21 11:55:17,772 - WARNING - No se pudo normalizar la fecha: con
# 2025-03-21 11:55:17,773 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,775 - WARNING - No se pudo normalizar la fecha: informacion
# 2025-03-21 11:55:17,777 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:17,778 - WARNING - No se pudo normalizar la fecha: patrimonio
# 2025-03-21 11:55:17,780 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,782 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,784 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,786 - WARNING - No se pudo normalizar la fecha: generando
# 2025-03-21 11:55:17,787 - WARNING - No se pudo normalizar la fecha: sinergia
# 2025-03-21 11:55:17,788 - WARNING - No se pudo normalizar la fecha: entre
# 2025-03-21 11:55:17,790 - WARNING - No se pudo normalizar la fecha: estrategias
# 2025-03-21 11:55:17,791 - WARNING - No se pudo normalizar la fecha: aprendizaje
# 2025-03-21 11:55:17,792 - WARNING - No se pudo normalizar la fecha: 8
# 2025-03-21 11:55:17,793 - WARNING - No se pudo normalizar la fecha: aprendizaje
# 2025-03-21 11:55:17,795 - WARNING - No se pudo normalizar la fecha: entidades
# 2025-03-21 11:55:17,796 - WARNING - No se pudo normalizar la fecha: del
# 2025-03-21 11:55:17,797 - WARNING - No se pudo normalizar la fecha: por
# 2025-03-21 11:55:17,798 - WARNING - No se pudo normalizar la fecha: del
# 2025-03-21 11:55:17,800 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,802 - WARNING - No se pudo normalizar la fecha: entidades
# 2025-03-21 11:55:17,804 - WARNING - No se pudo normalizar la fecha: instituciones
# 2025-03-21 11:55:17,806 - WARNING - No se pudo normalizar la fecha: instituciones
# 2025-03-21 11:55:17,810 - WARNING - No se pudo normalizar la fecha: educativas
# 2025-03-21 11:55:17,811 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,812 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,813 - WARNING - No se pudo normalizar la fecha: formacion
# 2025-03-21 11:55:17,818 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,819 - WARNING - No se pudo normalizar la fecha: artesanales
# 2025-03-21 11:55:17,821 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,822 - WARNING - No se pudo normalizar la fecha: facilitar
# 2025-03-21 11:55:17,824 - WARNING - No se pudo normalizar la fecha: 1
# 2025-03-21 11:55:17,828 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:17,830 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,831 - WARNING - No se pudo normalizar la fecha: disposiciones
# 2025-03-21 11:55:17,833 - WARNING - No se pudo normalizar la fecha: normativas
# 2025-03-21 11:55:17,835 - WARNING - No se pudo normalizar la fecha: Articulo
# 2025-03-21 11:55:17,837 - WARNING - No se pudo normalizar la fecha: 20
# 2025-03-21 11:55:17,839 - WARNING - No se pudo normalizar la fecha: del
# 2025-03-21 11:55:17,841 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,842 - WARNING - No se pudo normalizar la fecha: 22
# 2025-03-21 11:55:17,843 - WARNING - No se pudo normalizar la fecha: entidades
# 2025-03-21 11:55:17,844 - WARNING - No se pudo normalizar la fecha: implementaran
# 2025-03-21 11:55:17,846 - WARNING - No se pudo normalizar la fecha: servicios
# 2025-03-21 11:55:17,847 - WARNING - No se pudo normalizar la fecha: cultura
# 2025-03-21 11:55:17,852 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,856 - WARNING - No se pudo normalizar la fecha: artesanales
# 2025-03-21 11:55:17,858 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,859 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,860 - WARNING - No se pudo normalizar la fecha: entrada
# 2025-03-21 11:55:17,861 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,861 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:17,862 - WARNING - No se pudo normalizar la fecha: entidades
# 2025-03-21 11:55:17,863 - WARNING - No se pudo normalizar la fecha: promoveran
# 2025-03-21 11:55:17,864 - WARNING - No se pudo normalizar la fecha: 24
# 2025-03-21 11:55:17,865 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,866 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,869 - WARNING - No se pudo normalizar la fecha: 25
# 2025-03-21 11:55:17,871 - WARNING - No se pudo normalizar la fecha: instituciones
# 2025-03-21 11:55:17,874 - WARNING - No se pudo normalizar la fecha: nu
# 2025-03-21 11:55:17,876 - WARNING - No se pudo normalizar la fecha: investigaciones
# 2025-03-21 11:55:17,879 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,881 - WARNING - No se pudo normalizar la fecha: 26
# 2025-03-21 11:55:17,885 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,889 - WARNING - No se pudo normalizar la fecha: informacion
# 2025-03-21 11:55:17,891 - WARNING - No se pudo normalizar la fecha: para
# 2025-03-21 11:55:17,894 - WARNING - No se pudo normalizar la fecha: formular
# 2025-03-21 11:55:17,896 - WARNING - No se pudo normalizar la fecha: politicas
# 2025-03-21 11:55:17,901 - WARNING - No se pudo normalizar la fecha: informacion
# 2025-03-21 11:55:17,921 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:17,924 - WARNING - No se pudo normalizar la fecha: lideraran
# 2025-03-21 11:55:17,926 - WARNING - No se pudo normalizar la fecha: implementara
# 2025-03-21 11:55:17,929 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:17,932 - WARNING - No se pudo normalizar la fecha: estimular
# 2025-03-21 11:55:17,936 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,939 - WARNING - No se pudo normalizar la fecha: reglamente
# 2025-03-21 11:55:17,941 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:17,943 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:17,957 - INFO - Metadatos guardados en: C:\Users\Jorge\OneDrive\Documents\proyect\document\json_output_2022\LEY-2184-2022plaintext.json
# 2025-03-21 11:55:18,033 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:18,035 - WARNING - No se pudo normalizar la fecha: las
# 2025-03-21 11:55:18,036 - WARNING - No se pudo normalizar la fecha: necesidades
# 2025-03-21 11:55:18,037 - WARNING - No se pudo normalizar la fecha: recursos
# 2025-03-21 11:55:18,039 - WARNING - No se pudo normalizar la fecha: presupuestales
# 2025-03-21 11:55:18,041 - WARNING - No se pudo normalizar la fecha: entidades
# 2025-03-21 11:55:18,044 - WARNING - No se pudo normalizar la fecha: territoriales
# 2025-03-21 11:55:18,045 - WARNING - No se pudo normalizar la fecha: para
# 2025-03-21 11:55:18,048 - WARNING - No se pudo normalizar la fecha: 2185
# 2025-03-21 11:55:18,050 - WARNING - No se pudo normalizar la fecha: 2185ENE2022
# 2025-03-21 11:55:18,054 - INFO - Metadatos guardados en: C:\Users\Jorge\OneDrive\Documents\proyect\document\json_output_2022\LEY-2185-2022plaintext.json
# 2025-03-21 11:55:18,159 - WARNING - No se pudo normalizar la fecha: nuevo
# 2025-03-21 11:55:18,160 - WARNING - No se pudo normalizar la fecha: al
# 2025-03-21 11:55:18,163 - WARNING - No se pudo normalizar la fecha: 1990
# 2025-03-21 11:55:18,167 - WARNING - No se pudo normalizar la fecha: cada
# 2025-03-21 11:55:18,169 - WARNING - No se pudo normalizar la fecha: para
# 2025-03-21 11:55:18,170 - WARNING - No se pudo normalizar la fecha: inversiones
# 2025-03-21 11:55:18,172 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:18,174 - WARNING - No se pudo normalizar la fecha: financiacion
# 2025-03-21 11:55:18,176 - WARNING - No se pudo normalizar la fecha: para
# 2025-03-21 11:55:18,178 - WARNING - No se pudo normalizar la fecha: otra
# 2025-03-21 11:55:18,180 - WARNING - No se pudo normalizar la fecha: con
# 2025-03-21 11:55:18,182 - WARNING - No se pudo normalizar la fecha: reunan
# 2025-03-21 11:55:18,184 - WARNING - No se pudo normalizar la fecha: con
# 2025-03-21 11:55:18,186 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:18,189 - WARNING - No se pudo normalizar la fecha: complementarias
# 2025-03-21 11:55:18,190 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:18,192 - WARNING - No se pudo normalizar la fecha: trata
# 2025-03-21 11:55:18,193 - WARNING - No se pudo normalizar la fecha: 1990
# 2025-03-21 11:55:18,194 - WARNING - No se pudo normalizar la fecha: alcanzar
# 2025-03-21 11:55:18,196 - WARNING - No se pudo normalizar la fecha: con
# 2025-03-21 11:55:18,200 - WARNING - No se pudo normalizar la fecha: quintas
# 2025-03-21 11:55:18,202 - WARNING - No se pudo normalizar la fecha: mecanismos
# 2025-03-21 11:55:18,203 - WARNING - No se pudo normalizar la fecha: implementados
# 2025-03-21 11:55:18,205 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:18,206 - WARNING - No se pudo normalizar la fecha: para
# 2025-03-21 11:55:18,207 - WARNING - No se pudo normalizar la fecha: inversiones
# 2025-03-21 11:55:18,209 - WARNING - No se pudo normalizar la fecha: mujeres
# 2025-03-21 11:55:18,210 - WARNING - No se pudo normalizar la fecha: rurales
# 2025-03-21 11:55:18,211 - WARNING - No se pudo normalizar la fecha: rurales
# 2025-03-21 11:55:18,212 - WARNING - No se pudo normalizar la fecha: inversiones
# 2025-03-21 11:55:18,214 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:18,222 - INFO - Metadatos guardados en: C:\Users\Jorge\OneDrive\Documents\proyect\document\json_output_2022\LEY-2186-2022plaintext.json
# 2025-03-21 11:55:18,310 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:18,311 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:18,313 - WARNING - No se pudo normalizar la fecha: todo
# 2025-03-21 11:55:18,319 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:18,322 - WARNING - No se pudo normalizar la fecha: funciones
# 2025-03-21 11:55:18,324 - WARNING - No se pudo normalizar la fecha: terrestres
# 2025-03-21 11:55:18,326 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:18,330 - WARNING - No se pudo normalizar la fecha: redes
# 2025-03-21 11:55:18,343 - WARNING - No se pudo normalizar la fecha: hospitalarias
# 2025-03-21 11:55:18,358 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:18,368 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:18,372 - WARNING - No se pudo normalizar la fecha: recursos
# 2025-03-21 11:55:18,377 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:18,379 - WARNING - No se pudo normalizar la fecha: regulacion
# 2025-03-21 11:55:18,381 - WARNING - No se pudo normalizar la fecha: habilitacion
# 2025-03-21 11:55:18,385 - WARNING - No se pudo normalizar la fecha: necesarios
# 2025-03-21 11:55:18,386 - WARNING - No se pudo normalizar la fecha: salud
# 2025-03-21 11:55:18,389 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:18,390 - WARNING - No se pudo normalizar la fecha: salud
# 2025-03-21 11:55:18,392 - WARNING - No se pudo normalizar la fecha: donde
# 2025-03-21 11:55:18,393 - WARNING - No se pudo normalizar la fecha: no
# 2025-03-21 11:55:18,395 - WARNING - No se pudo normalizar la fecha: exigir
# 2025-03-21 11:55:18,396 - WARNING - No se pudo normalizar la fecha: requisitos
# 2025-03-21 11:55:18,400 - WARNING - No se pudo normalizar la fecha: establecidos
# 2025-03-21 11:55:18,402 - WARNING - No se pudo normalizar la fecha: articulo
# 2025-03-21 11:55:18,404 - WARNING - No se pudo normalizar la fecha: que
# 2025-03-21 11:55:18,406 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:18,407 - WARNING - No se pudo normalizar la fecha: 2187
# 2025-03-21 11:55:18,419 - INFO - Metadatos guardados en: C:\Users\Jorge\OneDrive\Documents\proyect\document\json_output_2022\LEY-2187-2022plaintext.json
# 2025-03-21 11:55:18,502 - WARNING - No se pudo normalizar la fecha: 1921
# 2025-03-21 11:55:18,503 - WARNING - No se pudo normalizar la fecha: por
# 2025-03-21 11:55:18,504 - WARNING - No se pudo normalizar la fecha: ganadera
# 2025-03-21 11:55:18,505 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:18,505 - WARNING - No se pudo normalizar la fecha: sabanas
# 2025-03-21 11:55:18,506 - WARNING - No se pudo normalizar la fecha: interés
# 2025-03-21 11:55:18,507 - WARNING - No se pudo normalizar la fecha: una
# 2025-03-21 11:55:18,508 - WARNING - No se pudo normalizar la fecha: subdivision
# 2025-03-21 11:55:18,509 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:18,510 - WARNING - No se pudo normalizar la fecha: sean
# 2025-03-21 11:55:18,511 - WARNING - No se pudo normalizar la fecha: necesarios
# 2025-03-21 11:55:18,511 - WARNING - No se pudo normalizar la fecha: sobre
# 2025-03-21 11:55:18,512 - WARNING - No se pudo normalizar la fecha: nivel
# 2025-03-21 11:55:18,513 - WARNING - No se pudo normalizar la fecha: nacional
# 2025-03-21 11:55:18,514 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:18,516 - WARNING - No se pudo normalizar la fecha: entidades
# 2025-03-21 11:55:18,516 - WARNING - No se pudo normalizar la fecha: recursos
# 2025-03-21 11:55:18,518 - WARNING - No se pudo normalizar la fecha: economicos
# 2025-03-21 11:55:18,520 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:18,521 - WARNING - No se pudo normalizar la fecha: 2188
# 2025-03-21 11:55:18,523 - INFO - Metadatos guardados en: C:\Users\Jorge\OneDrive\Documents\proyect\document\json_output_2022\LEY-2188-2022plaintext.json
# 2025-03-21 11:55:18,611 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:18,612 - WARNING - No se pudo normalizar la fecha: 2004
# 2025-03-21 11:55:18,613 - WARNING - No se pudo normalizar la fecha: toda
# 2025-03-21 11:55:18,615 - WARNING - No se pudo normalizar la fecha: desde
# 2025-03-21 11:55:18,617 - WARNING - No se pudo normalizar la fecha: servicios
# 2025-03-21 11:55:18,619 - WARNING - No se pudo normalizar la fecha: estara
# 2025-03-21 11:55:18,620 - WARNING - No se pudo normalizar la fecha: 10%
# 2025-03-21 11:55:18,621 - WARNING - No se pudo normalizar la fecha: 1993
# 2025-03-21 11:55:18,622 - WARNING - No se pudo normalizar la fecha: 2004
# 2025-03-21 11:55:18,624 - WARNING - No se pudo normalizar la fecha: aduanero
# 2025-03-21 11:55:18,625 - WARNING - No se pudo normalizar la fecha: 1
# 2025-03-21 11:55:18,626 - WARNING - No se pudo normalizar la fecha: comercio
# 2025-03-21 11:55:18,626 - WARNING - No se pudo normalizar la fecha: electronico
# 2025-03-21 11:55:18,627 - WARNING - No se pudo normalizar la fecha: obligaciones
# 2025-03-21 11:55:18,629 - WARNING - No se pudo normalizar la fecha: de
# 2025-03-21 11:55:18,630 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:18,633 - WARNING - No se pudo normalizar la fecha: al
# 2025-03-21 11:55:18,635 - WARNING - No se pudo normalizar la fecha: aduanero
# 2025-03-21 11:55:18,636 - WARNING - No se pudo normalizar la fecha: otra
# 2025-03-21 11:55:18,637 - WARNING - No se pudo normalizar la fecha: no
# 2025-03-21 11:55:18,639 - WARNING - No se pudo normalizar la fecha: trafico
# 2025-03-21 11:55:18,640 - WARNING - No se pudo normalizar la fecha: envie
# 2025-03-21 11:55:18,641 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:18,643 - WARNING - No se pudo normalizar la fecha: trafico
# 2025-03-21 11:55:18,644 - WARNING - No se pudo normalizar la fecha: 1369
# 2025-03-21 11:55:18,647 - WARNING - No se pudo normalizar la fecha: 2004
# 2025-03-21 11:55:18,650 - WARNING - No se pudo normalizar la fecha: acciones
# 2025-03-21 11:55:18,654 - WARNING - No se pudo normalizar la fecha: proveer
# 2025-03-21 11:55:18,655 - WARNING - No se pudo normalizar la fecha: impulsar
# 2025-03-21 11:55:18,656 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:18,657 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:18,659 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:18,660 - WARNING - No se pudo normalizar la fecha: aprovechada
# 2025-03-21 11:55:18,662 - WARNING - No se pudo normalizar la fecha: haya
# 2025-03-21 11:55:18,663 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:18,664 - WARNING - No se pudo normalizar la fecha: comercio
# 2025-03-21 11:55:18,665 - WARNING - No se pudo normalizar la fecha: entidades
# 2025-03-21 11:55:18,666 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:18,669 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:18,673 - INFO - Metadatos guardados en: C:\Users\Jorge\OneDrive\Documents\proyect\document\json_output_2022\LEY-2189-2022plaintext.json
# 2025-03-21 11:55:18,774 - WARNING - No se pudo normalizar la fecha: relaciones
# 2025-03-21 11:55:18,775 - WARNING - No se pudo normalizar la fecha: relaciones
# 2025-03-21 11:55:18,776 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:18,777 - WARNING - No se pudo normalizar la fecha: normativa
# 2025-03-21 11:55:18,777 - WARNING - No se pudo normalizar la fecha: relacionadas
# 2025-03-21 11:55:18,778 - WARNING - No se pudo normalizar la fecha: la
# 2025-03-21 11:55:18,779 - WARNING - No se pudo normalizar la fecha: jornada
# 2025-03-21 11:55:18,779 - WARNING - No se pudo normalizar la fecha: parte
# 2025-03-21 11:55:18,780 - WARNING - No se pudo normalizar la fecha: formular
# 2025-03-21 11:55:18,781 - WARNING - No se pudo normalizar la fecha: ordenes
# 2025-03-21 11:55:18,783 - WARNING - No se pudo normalizar la fecha: requerimientos
# 2025-03-21 11:55:18,784 - WARNING - No se pudo normalizar la fecha: al
# 2025-03-21 11:55:18,786 - WARNING - No se pudo normalizar la fecha: al
# 2025-03-21 11:55:18,787 - WARNING - No se pudo normalizar la fecha: que
# 2025-03-21 11:55:18,789 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:18,789 - WARNING - No se pudo normalizar la fecha: ineficaz
# 2025-03-21 11:55:18,790 - WARNING - No se pudo normalizar la fecha: 2
# 2025-03-21 11:55:18,791 - WARNING - No se pudo normalizar la fecha: una
# 2025-03-21 11:55:18,793 - WARNING - No se pudo normalizar la fecha: no
# 2025-03-21 11:55:18,794 - WARNING - No se pudo normalizar la fecha: una
# 2025-03-21 11:55:18,796 - WARNING - No se pudo normalizar la fecha: medios
# 2025-03-21 11:55:18,801 - WARNING - No se pudo normalizar la fecha: una
# 2025-03-21 11:55:18,804 - WARNING - No se pudo normalizar la fecha: necesarios
# 2025-03-21 11:55:18,806 - WARNING - No se pudo normalizar la fecha: inexistencia
# 2025-03-21 11:55:18,808 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:18,810 - WARNING - No se pudo normalizar la fecha: anexar
# 2025-03-21 11:55:18,812 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:18,816 - WARNING - No se pudo normalizar la fecha: 2191
# 2025-03-21 11:55:18,823 - INFO - Metadatos guardados en: C:\Users\Jorge\OneDrive\Documents\proyect\document\json_output_2022\LEY-2191-2022plaintext.json
# 2025-03-21 11:55:18,935 - WARNING - No se pudo normalizar la fecha: 187
# 2025-03-21 11:55:18,937 - WARNING - No se pudo normalizar la fecha: 1834
# 2025-03-21 11:55:18,939 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:18,940 - WARNING - No se pudo normalizar la fecha: entidades
# 2025-03-21 11:55:18,941 - WARNING - No se pudo normalizar la fecha: instancia
# 2025-03-21 11:55:18,943 - WARNING - No se pudo normalizar la fecha: representacion
# 2025-03-21 11:55:18,945 - WARNING - No se pudo normalizar la fecha: autorizado
# 2025-03-21 11:55:18,946 - WARNING - No se pudo normalizar la fecha: requeridos
# 2025-03-21 11:55:18,948 - WARNING - No se pudo normalizar la fecha: 1
# 2025-03-21 11:55:18,950 - WARNING - No se pudo normalizar la fecha: 2192
# 2025-03-21 11:55:18,954 - INFO - Metadatos guardados en: C:\Users\Jorge\OneDrive\Documents\proyect\document\json_output_2022\LEY-2192-2022plaintext.json
# 2025-03-21 11:55:19,213 - WARNING - No se pudo normalizar la fecha: que
# 2025-03-21 11:55:19,214 - WARNING - No se pudo normalizar la fecha: anos
# 2025-03-21 11:55:19,218 - WARNING - No se pudo normalizar la fecha: adicionales
# 2025-03-21 11:55:19,220 - WARNING - No se pudo normalizar la fecha: al
# 2025-03-21 11:55:19,222 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:19,224 - WARNING - No se pudo normalizar la fecha: util
# 2025-03-21 11:55:19,226 - WARNING - No se pudo normalizar la fecha: entre
# 2025-03-21 11:55:19,228 - WARNING - No se pudo normalizar la fecha: la
# 2025-03-21 11:55:19,230 - WARNING - No se pudo normalizar la fecha: 1993
# 2025-03-21 11:55:19,232 - WARNING - No se pudo normalizar la fecha: modificado
# 2025-03-21 11:55:19,235 - WARNING - No se pudo normalizar la fecha: sus
# 2025-03-21 11:55:19,236 - WARNING - No se pudo normalizar la fecha: estan
# 2025-03-21 11:55:19,238 - WARNING - No se pudo normalizar la fecha: 1
# 2025-03-21 11:55:19,240 - WARNING - No se pudo normalizar la fecha: 2198
# 2025-03-21 11:55:19,241 - WARNING - No se pudo normalizar la fecha: 1993
# 2025-03-21 11:55:19,242 - WARNING - No se pudo normalizar la fecha: ruta
# 2025-03-21 11:55:19,244 - WARNING - No se pudo normalizar la fecha: existente
# 2025-03-21 11:55:19,245 - WARNING - No se pudo normalizar la fecha: nuevas
# 2025-03-21 11:55:19,246 - WARNING - No se pudo normalizar la fecha: infraestructuras
# 2025-03-21 11:55:19,247 - WARNING - No se pudo normalizar la fecha: autorizada
# 2025-03-21 11:55:19,249 - WARNING - No se pudo normalizar la fecha: ruta
# 2025-03-21 11:55:19,251 - WARNING - No se pudo normalizar la fecha: nuevas
# 2025-03-21 11:55:19,253 - WARNING - No se pudo normalizar la fecha: ruta
# 2025-03-21 11:55:19,255 - WARNING - No se pudo normalizar la fecha: inicialmente
# 2025-03-21 11:55:19,257 - WARNING - No se pudo normalizar la fecha: treinta
# 2025-03-21 11:55:19,260 - WARNING - No se pudo normalizar la fecha: ruta
# 2025-03-21 11:55:19,262 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:19,263 - WARNING - No se pudo normalizar la fecha: ambos
# 2025-03-21 11:55:19,272 - WARNING - No se pudo normalizar la fecha: ruta
# 2025-03-21 11:55:19,273 - WARNING - No se pudo normalizar la fecha: 1996
# 2025-03-21 11:55:19,275 - WARNING - No se pudo normalizar la fecha: operacion
# 2025-03-21 11:55:19,277 - WARNING - No se pudo normalizar la fecha: nabilitadas
# 2025-03-21 11:55:19,282 - WARNING - No se pudo normalizar la fecha: que
# 2025-03-21 11:55:19,284 - WARNING - No se pudo normalizar la fecha: ofrecer
# 2025-03-21 11:55:19,286 - WARNING - No se pudo normalizar la fecha: nuevas
# 2025-03-21 11:55:19,289 - WARNING - No se pudo normalizar la fecha: rutas
# 2025-03-21 11:55:19,291 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:55:19,293 - WARNING - No se pudo normalizar la fecha: vias
# 2025-03-21 11:55:19,295 - WARNING - No se pudo normalizar la fecha: obtener
# 2025-03-21 11:55:19,297 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:19,299 - WARNING - No se pudo normalizar la fecha: bajo
# 2025-03-21 11:55:19,302 - WARNING - No se pudo normalizar la fecha: indicar
# 2025-03-21 11:55:19,304 - WARNING - No se pudo normalizar la fecha: inexistencia
# 2025-03-21 11:55:19,306 - WARNING - No se pudo normalizar la fecha: ruta
# 2025-03-21 11:55:19,308 - WARNING - No se pudo normalizar la fecha: afecta
# 2025-03-21 11:55:19,310 - WARNING - No se pudo normalizar la fecha: intermedias
# 2025-03-21 11:55:19,313 - WARNING - No se pudo normalizar la fecha: para
# 2025-03-21 11:55:19,314 - WARNING - No se pudo normalizar la fecha: entre
# 2025-03-21 11:55:19,322 - WARNING - No se pudo normalizar la fecha: 2198
# 2025-03-21 11:55:19,324 - WARNING - No se pudo normalizar la fecha: medianas
# 2025-03-21 11:55:19,325 - WARNING - No se pudo normalizar la fecha: grandes
# 2025-03-21 11:55:19,327 - WARNING - No se pudo normalizar la fecha: rutas
# 2025-03-21 11:55:19,331 - WARNING - No se pudo normalizar la fecha: rutas
# 2025-03-21 11:55:19,334 - WARNING - No se pudo normalizar la fecha: intermedias
# 2025-03-21 11:55:19,335 - WARNING - No se pudo normalizar la fecha: 1996
# 2025-03-21 11:55:19,336 - WARNING - No se pudo normalizar la fecha: misma
# 2025-03-21 11:55:19,338 - WARNING - No se pudo normalizar la fecha: interesados
# 2025-03-21 11:55:19,339 - WARNING - No se pudo normalizar la fecha: que
# 2025-03-21 11:55:19,341 - WARNING - No se pudo normalizar la fecha: seleccionar
# 2025-03-21 11:55:19,342 - WARNING - No se pudo normalizar la fecha: no
# 2025-03-21 11:55:19,344 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:19,345 - WARNING - No se pudo normalizar la fecha: 1705
# 2025-03-21 11:55:19,347 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:19,351 - WARNING - No se pudo normalizar la fecha: nueve
# 2025-03-21 11:55:19,353 - WARNING - No se pudo normalizar la fecha: para
# 2025-03-21 11:55:19,354 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:19,356 - WARNING - No se pudo normalizar la fecha: nueve
# 2025-03-21 11:55:19,358 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:55:19,360 - WARNING - No se pudo normalizar la fecha: 14
# ...
# 2025-03-21 11:57:15,739 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:57:15,741 - WARNING - No se pudo normalizar la fecha: recae
# 2025-03-21 11:57:15,742 - WARNING - No se pudo normalizar la fecha: 13
# 2025-03-21 11:57:15,743 - WARNING - No se pudo normalizar la fecha: una
# 2025-03-21 11:57:15,745 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:57:15,746 - WARNING - No se pudo normalizar la fecha: requisitos
# 2025-03-21 11:57:15,748 - WARNING - No se pudo normalizar la fecha: consultaran
# 2025-03-21 11:57:15,749 - WARNING - No se pudo normalizar la fecha: entre
# 2025-03-21 11:57:15,751 - WARNING - No se pudo normalizar la fecha: cualquier
# 2025-03-21 11:57:15,752 - WARNING - No se pudo normalizar la fecha: resuelta
# 2025-03-21 11:57:15,754 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:57:15,755 - WARNING - No se pudo normalizar la fecha: una
# 2025-03-21 11:57:15,756 - WARNING - No se pudo normalizar la fecha: hagan
# 2025-03-21 11:57:15,759 - WARNING - No se pudo normalizar la fecha: términos
# 2025-03-21 11:57:15,761 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:57:15,762 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:57:15,764 - WARNING - No se pudo normalizar la fecha: terminar
# 2025-03-21 11:57:15,766 - WARNING - No se pudo normalizar la fecha: la
# 2025-03-21 11:57:15,768 - WARNING - No se pudo normalizar la fecha: ultima
# 2025-03-21 11:57:15,769 - WARNING - No se pudo normalizar la fecha: nota
# 2025-03-21 11:57:15,771 - WARNING - No se pudo normalizar la fecha: refiere
# 2025-03-21 11:57:15,773 - WARNING - No se pudo normalizar la fecha: impulsada
# 2025-03-21 11:57:15,774 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:57:15,776 - WARNING - No se pudo normalizar la fecha: nucleo
# 2025-03-21 11:57:15,777 - WARNING - No se pudo normalizar la fecha: internacional
# 2025-03-21 11:57:15,779 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:57:15,780 - WARNING - No se pudo normalizar la fecha: relaciones
# 2025-03-21 11:57:15,782 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:57:15,784 - WARNING - No se pudo normalizar la fecha: 227
# 2025-03-21 11:57:15,785 - WARNING - No se pudo normalizar la fecha: relaciones
# 2025-03-21 11:57:15,786 - WARNING - No se pudo normalizar la fecha: relaciones
# 2025-03-21 11:57:15,788 - WARNING - No se pudo normalizar la fecha: integracion
# 2025-03-21 11:57:15,790 - WARNING - No se pudo normalizar la fecha: sobre
# 2025-03-21 11:57:15,791 - WARNING - No se pudo normalizar la fecha: el
# 2025-03-21 11:57:15,792 - WARNING - No se pudo normalizar la fecha: sobre
# 2025-03-21 11:57:15,794 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:57:15,796 - WARNING - No se pudo normalizar la fecha: 1944
# 2025-03-21 11:57:15,798 - WARNING - No se pudo normalizar la fecha: que
# 2025-03-21 11:57:15,799 - WARNING - No se pudo normalizar la fecha: 1998
# 2025-03-21 11:57:15,800 - WARNING - No se pudo normalizar la fecha: 13
# 2025-03-21 11:57:15,801 - WARNING - No se pudo normalizar la fecha: internacionales
# 2025-03-21 11:57:15,802 - WARNING - No se pudo normalizar la fecha: treinta
# 2025-03-21 11:57:15,804 - WARNING - No se pudo normalizar la fecha: periodo
# 2025-03-21 11:57:15,806 - WARNING - No se pudo normalizar la fecha: cada
# 2025-03-21 11:57:15,807 - WARNING - No se pudo normalizar la fecha: 992
# 2025-03-21 11:57:15,808 - WARNING - No se pudo normalizar la fecha: ano
# 2025-03-21 11:57:15,810 - WARNING - No se pudo normalizar la fecha: se
# 2025-03-21 11:57:15,811 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:57:15,813 - WARNING - No se pudo normalizar la fecha: en
# 2025-03-21 11:57:15,814 - WARNING - No se pudo normalizar la fecha: 1944
# 2025-03-21 11:57:15,815 - WARNING - No se pudo normalizar la fecha: que
# 2025-03-21 11:57:15,816 - WARNING - No se pudo normalizar la fecha: 2280
# 2025-03-21 11:57:15,818 - WARNING - No se pudo normalizar la fecha: 2280
# 2025-03-21 11:57:15,819 - WARNING - No se pudo normalizar la fecha: articulo
# 2025-03-21 11:57:15,829 - INFO - Metadatos guardados en: C:\Users\Jorge\OneDrive\Documents\proyect\document\json_output_2022\LEY-2280-2022plaintext.json
# c:\Users\Jorge\anaconda3\envs\Extract\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "2184 6ENE2022 LEY No. POR MEDIO DE LA CUAL SE DICT..." with entities "[(0, 4, 'NUMERO_LEY'), (5, 13, 'FECHA'), (14, 236,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\Extract\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "2185 ENE2022 LEY No "POR MEDIO DE LA CUAL SE CREA ..." with entities "[(0, 4, 'NUMERO_LEY'), (5, 12, 'FECHA'), (13, 120,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\Extract\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "8FEB2022 - .  LEY ORGANICA No2199 "POR MEDIO DE LA..." with entities "[(0, 0, '8'), (22, 28, '8'), (30, 30, '122')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# c:\Users\Jorge\anaconda3\envs\Extract\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "2182 3ENE2022 LEY No "POR MEDIO DEL CUAL SE MODIFI..." with entities "[(0, 4, 'NUMERO_LEY'), (5, 13, 'FECHA'), (14, 103,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# [2025-03-21 11:57:16,299] [INFO] Created vocabulary
# 2025-03-21 11:57:16,299 - INFO - Created vocabulary
# [2025-03-21 11:57:16,303] [INFO] Finished initializing nlp object
# 2025-03-21 11:57:16,303 - INFO - Finished initializing nlp object
# Época 1, pérdidas: {'ner': 39.27273067086935}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 1.0, 'ents_r': 0.5, 'ents_f': 0.6666666666666666, 'ents_per_type': {'NUMERO_LEY': {'p': 1.0, 'r': 1.0, 'f': 1.0}, 'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 3647.915363472408}
# Época 2, pérdidas: {'ner': 48.992600828409195}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 3552.660803249696}
# Época 3, pérdidas: {'ner': 38.0771265514195}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 5627.066192718658}
# Época 4, pérdidas: {'ner': 37.54566615819931}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 4909.58186839221}
# Época 5, pérdidas: {'ner': 36.827897096052766}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 4879.040427439004}
# Época 6, pérdidas: {'ner': 35.9754843339324}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 4390.699033381824}
# Época 7, pérdidas: {'ner': 34.89653395861387}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 6282.558026181745}
# Época 8, pérdidas: {'ner': 33.80893816612661}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 5154.971322890711}
# Época 9, pérdidas: {'ner': 32.29726168978959}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 3877.2839721384107}
# Época 10, pérdidas: {'ner': 29.745957251638174}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 3546.518508386023}
# Época 11, pérdidas: {'ner': 26.451645150780678}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 2316.8035815520816}
# Época 12, pérdidas: {'ner': 22.263568568741903}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 6066.734074100368}
# Época 13, pérdidas: {'ner': 16.228958022082224}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 6804.456930386461}
# Época 14, pérdidas: {'ner': 9.711121175234439}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 4243.206453674715}
# Época 15, pérdidas: {'ner': 6.542987627835828}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 5277.508988802724}
# Época 16, pérdidas: {'ner': 6.036951502697548}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 4165.437274769794}
# Época 17, pérdidas: {'ner': 6.383264407644589}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 2625.188686338753}
# Época 18, pérdidas: {'ner': 6.800668752203068}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 4923.177898707983}
# Época 19, pérdidas: {'ner': 6.608031911201294}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 2756.2762695193182}
# Época 20, pérdidas: {'ner': 5.870055036351734}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 3451.4496047291245}
# Época 21, pérdidas: {'ner': 5.490505200830617}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 3671.408898452742}
# Época 22, pérdidas: {'ner': 4.254361210398643}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 3124.674518481618}
# Época 23, pérdidas: {'ner': 3.3263720744541034}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 4650.98251813073}
# Época 24, pérdidas: {'ner': 3.1345138456977395}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 3845.7224391652317}
# Época 25, pérdidas: {'ner': 2.53203139696094}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 4031.648450719826}
# Época 26, pérdidas: {'ner': 2.342506836945942}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 4515.861978273547}
# Época 27, pérdidas: {'ner': 2.0653050821229386}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 0.0, 'ents_r': 0.0, 'ents_f': 0.0, 'ents_per_type': {'FECHA': {'p': 0.0, 'r': 0.0, 'f': 0.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 4168.475893702934}
# Época 28, pérdidas: {'ner': 1.8022476854624485}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 1.0, 'ents_r': 0.5, 'ents_f': 0.6666666666666666, 'ents_per_type': {'FECHA': {'p': 1.0, 'r': 1.0, 'f': 1.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 3290.2854270607068}
# Época 29, pérdidas: {'ner': 1.558640002306086}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 1.0, 'ents_r': 0.5, 'ents_f': 0.6666666666666666, 'ents_per_type': {'FECHA': {'p': 1.0, 'r': 1.0, 'f': 1.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 2642.356979455364}
# Época 30, pérdidas: {'ner': 1.2708994984773978}
#   Resultados en validación: {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'ents_p': 1.0, 'ents_r': 0.5, 'ents_f': 0.6666666666666666, 'ents_per_type': {'FECHA': {'p': 1.0, 'r': 1.0, 'f': 1.0}, 'NUMERO_LEY': {'p': 0.0, 'r': 0.0, 'f': 0.0}}, 'speed': 3455.7235416207805}
# Modelo guardado en: modelo_leyes_epigrafe
# 2353 NUMERO_LEY
# Fecha final: 17/04/2024
